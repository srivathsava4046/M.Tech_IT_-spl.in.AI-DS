# %%
import os
import cv2
import numpy as np
import csv

# Function to extract 15 frames from each video
def extract_frames(video_path, num_frames=15):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)  # Equally spaced indices
    frames = []
    
    for i in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = cap.read()
        if ret:
            frames.append(frame)
    cap.release()
    return frames

# Function to create dataset with frames and labels, skipping already processed videos
def create_dataset(folders, output_dir, num_frames=15):
    dataset = []
    
    # Read existing CSV if available to skip processed files
    processed_files = set()
    if os.path.exists(csv_file):
        with open(csv_file, 'r') as f:
            reader = csv.reader(f)
            next(reader)  # Skip header
            processed_files = {row[0].split('_frame_')[0] for row in reader}

    for folder, label in folders:
        for video_file in os.listdir(folder):
            video_path = os.path.join(folder, video_file)
            base_filename = os.path.splitext(video_file)[0]
            
            # Skip videos that are already processed
            if base_filename in processed_files:
                print(f"Skipping {video_file}, already processed.")
                continue
            
            frames = extract_frames(video_path, num_frames)
            for i, frame in enumerate(frames):
                frame_filename = f"{base_filename}_frame_{i}.jpg"
                frame_path = os.path.join(output_dir, frame_filename)
                cv2.imwrite(frame_path, frame)
                dataset.append((frame_path, label))
            
            # Write frames to the CSV after each video is processed to ensure progress is saved
            with open(csv_file, 'a', newline='') as f:
                writer = csv.writer(f)
                writer.writerows([(f"{base_filename}_frame_{i}.jpg", label) for i in range(len(frames))])
    
    return dataset

# Define your video folders and corresponding labels
folders = [
    ('F:\Project\Dataset\Dataset\original_sequences\youtube\c40\\videos', 'real'),
    ('F:\Project\Dataset\Dataset\manipulated_sequences\Deepfakes\c40\\videos', 'fake')
]

# Define output directory for frames
output_dir = 'frames_dataset'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# CSV file path
csv_file = 'video_frames.csv'

# Create the dataset
dataset = create_dataset(folders, output_dir)

print(f"Dataset updated and saved as {csv_file}.")
# Out:
# Skipping 000.mp4, already processed.
# Skipping 001.mp4, already processed.
# Skipping 002.mp4, already processed.
# Skipping 003.mp4, already processed.
# Skipping 004.mp4, already processed.
# Skipping 005.mp4, already processed.
# Skipping 006.mp4, already processed.
# Skipping 007.mp4, already processed.
# Skipping 008.mp4, already processed.
# Skipping 009.mp4, already processed.
# Skipping 010.mp4, already processed.
# Skipping 011.mp4, already processed.
# Skipping 012.mp4, already processed.
# Skipping 013.mp4, already processed.
# Skipping 014.mp4, already processed.
# Skipping 015.mp4, already processed.
# Skipping 016.mp4, already processed.
# Skipping 017.mp4, already processed.
# Skipping 018.mp4, already processed.
# Skipping 019.mp4, already processed.
# Skipping 020.mp4, already processed.
# Skipping 021.mp4, already processed.
# Skipping 022.mp4, already processed.
# Skipping 023.mp4, already processed.
# Skipping 024.mp4, already processed.
# Skipping 025.mp4, already processed.
# Skipping 026.mp4, already processed.
# Skipping 027.mp4, already processed.
# Skipping 028.mp4, already processed.
# Skipping 029.mp4, already processed.
# Skipping 030.mp4, already processed.
# Skipping 031.mp4, already processed.
# Skipping 032.mp4, already processed.
# Skipping 033.mp4, already processed.
# Skipping 034.mp4, already processed.
# Skipping 035.mp4, already processed.
# Skipping 036.mp4, already processed.
# Skipping 037.mp4, already processed.
# Skipping 038.mp4, already processed.
# Skipping 039.mp4, already processed.
# Skipping 040.mp4, already processed.
# Skipping 041.mp4, already processed.
# Skipping 042.mp4, already processed.
# Skipping 043.mp4, already processed.
# Skipping 044.mp4, already processed.
# Skipping 045.mp4, already processed.
# Skipping 046.mp4, already processed.
# Skipping 047.mp4, already processed.
# Skipping 048.mp4, already processed.
# Skipping 049.mp4, already processed.
# Skipping 050.mp4, already processed.
# Skipping 051.mp4, already processed.
# Skipping 052.mp4, already processed.
# Skipping 053.mp4, already processed.
# Skipping 054.mp4, already processed.
# Skipping 055.mp4, already processed.
# Skipping 056.mp4, already processed.
# Skipping 057.mp4, already processed.
# Skipping 058.mp4, already processed.
# Skipping 059.mp4, already processed.
# Skipping 060.mp4, already processed.
# Skipping 061.mp4, already processed.
# Skipping 062.mp4, already processed.
# Skipping 063.mp4, already processed.
# Skipping 064.mp4, already processed.
# Skipping 065.mp4, already processed.
# Skipping 066.mp4, already processed.
# Skipping 067.mp4, already processed.
# Skipping 068.mp4, already processed.
# Skipping 069.mp4, already processed.
# Skipping 070.mp4, already processed.
# Skipping 071.mp4, already processed.
# Skipping 072.mp4, already processed.
# Skipping 073.mp4, already processed.
# Skipping 074.mp4, already processed.
# Skipping 075.mp4, already processed.
# Skipping 076.mp4, already processed.
# Skipping 077.mp4, already processed.
# Skipping 078.mp4, already processed.
# Skipping 079.mp4, already processed.
# Skipping 080.mp4, already processed.
# Skipping 081.mp4, already processed.
# Skipping 082.mp4, already processed.
# Skipping 083.mp4, already processed.
# Skipping 084.mp4, already processed.
# Skipping 085.mp4, already processed.
# Skipping 086.mp4, already processed.
# Skipping 087.mp4, already processed.
# Skipping 088.mp4, already processed.
# Skipping 089.mp4, already processed.
# Skipping 090.mp4, already processed.
# Skipping 091.mp4, already processed.
# Skipping 092.mp4, already processed.
# Skipping 093.mp4, already processed.
# Skipping 094.mp4, already processed.
# Skipping 095.mp4, already processed.
# Skipping 096.mp4, already processed.
# Skipping 097.mp4, already processed.
# Skipping 098.mp4, already processed.
# Skipping 099.mp4, already processed.
# Skipping 100.mp4, already processed.
# Skipping 101.mp4, already processed.
# Skipping 102.mp4, already processed.
# Skipping 103.mp4, already processed.
# Skipping 104.mp4, already processed.
# Skipping 105.mp4, already processed.
# Skipping 106.mp4, already processed.
# Skipping 107.mp4, already processed.
# Skipping 108.mp4, already processed.
# Skipping 109.mp4, already processed.
# Skipping 110.mp4, already processed.
# Skipping 111.mp4, already processed.
# Skipping 112.mp4, already processed.
# Skipping 113.mp4, already processed.
# Skipping 114.mp4, already processed.
# Skipping 115.mp4, already processed.
# Skipping 116.mp4, already processed.
# Skipping 117.mp4, already processed.
# Skipping 118.mp4, already processed.
# Skipping 119.mp4, already processed.
# Skipping 120.mp4, already processed.
# Skipping 121.mp4, already processed.
# Skipping 122.mp4, already processed.
# Skipping 123.mp4, already processed.
# Skipping 124.mp4, already processed.
# Skipping 125.mp4, already processed.
# Skipping 126.mp4, already processed.
# Skipping 127.mp4, already processed.
# Skipping 128.mp4, already processed.
# Skipping 129.mp4, already processed.
# Skipping 130.mp4, already processed.
# Skipping 131.mp4, already processed.
# Skipping 132.mp4, already processed.
# Skipping 133.mp4, already processed.
# Skipping 134.mp4, already processed.
# Skipping 135.mp4, already processed.
# Skipping 136.mp4, already processed.
# Skipping 137.mp4, already processed.
# Skipping 138.mp4, already processed.
# Skipping 139.mp4, already processed.
# Skipping 140.mp4, already processed.
# Skipping 141.mp4, already processed.
# Skipping 142.mp4, already processed.
# Skipping 143.mp4, already processed.
# Skipping 144.mp4, already processed.
# Skipping 145.mp4, already processed.
# Skipping 146.mp4, already processed.
# Skipping 147.mp4, already processed.
# Skipping 148.mp4, already processed.
# Skipping 149.mp4, already processed.
# Skipping 150.mp4, already processed.
# Skipping 151.mp4, already processed.
# Skipping 152.mp4, already processed.
# Skipping 153.mp4, already processed.
# Skipping 154.mp4, already processed.
# Skipping 155.mp4, already processed.
# Skipping 156.mp4, already processed.
# Skipping 157.mp4, already processed.
# Skipping 158.mp4, already processed.
# Skipping 159.mp4, already processed.
# Skipping 160.mp4, already processed.
# Skipping 161.mp4, already processed.
# Skipping 162.mp4, already processed.
# Skipping 163.mp4, already processed.
# Skipping 164.mp4, already processed.
# Skipping 165.mp4, already processed.
# Skipping 166.mp4, already processed.
# Skipping 167.mp4, already processed.
# Skipping 168.mp4, already processed.
# Skipping 169.mp4, already processed.
# Skipping 170.mp4, already processed.
# Skipping 171.mp4, already processed.
# Skipping 172.mp4, already processed.
# Skipping 173.mp4, already processed.
# Skipping 174.mp4, already processed.
# Skipping 175.mp4, already processed.
# Skipping 176.mp4, already processed.
# Skipping 177.mp4, already processed.
# Skipping 178.mp4, already processed.
# Skipping 179.mp4, already processed.
# Skipping 180.mp4, already processed.
# Skipping 181.mp4, already processed.
# Skipping 182.mp4, already processed.
# Skipping 183.mp4, already processed.
# Skipping 184.mp4, already processed.
# Skipping 185.mp4, already processed.
# Skipping 186.mp4, already processed.
# Skipping 187.mp4, already processed.
# Skipping 188.mp4, already processed.
# Skipping 189.mp4, already processed.
# Skipping 190.mp4, already processed.
# Skipping 191.mp4, already processed.
# Skipping 192.mp4, already processed.
# Skipping 193.mp4, already processed.
# Skipping 194.mp4, already processed.
# Skipping 195.mp4, already processed.
# Skipping 196.mp4, already processed.
# Skipping 197.mp4, already processed.
# Skipping 198.mp4, already processed.
# Skipping 199.mp4, already processed.
# Skipping 200.mp4, already processed.
# Skipping 201.mp4, already processed.
# Skipping 202.mp4, already processed.
# Skipping 203.mp4, already processed.
# Skipping 204.mp4, already processed.
# Skipping 205.mp4, already processed.
# Skipping 206.mp4, already processed.
# Skipping 207.mp4, already processed.
# Skipping 208.mp4, already processed.
# Skipping 209.mp4, already processed.
# Skipping 210.mp4, already processed.
# Skipping 211.mp4, already processed.
# Skipping 212.mp4, already processed.
# Skipping 213.mp4, already processed.
# Skipping 214.mp4, already processed.
# Skipping 215.mp4, already processed.
# Skipping 216.mp4, already processed.
# Skipping 217.mp4, already processed.
# Skipping 218.mp4, already processed.
# Skipping 219.mp4, already processed.
# Skipping 220.mp4, already processed.
# Skipping 221.mp4, already processed.
# Skipping 222.mp4, already processed.
# Skipping 223.mp4, already processed.
# Skipping 224.mp4, already processed.
# Skipping 225.mp4, already processed.
# Skipping 226.mp4, already processed.
# Skipping 227.mp4, already processed.
# Skipping 228.mp4, already processed.
# Skipping 229.mp4, already processed.
# Skipping 230.mp4, already processed.
# Skipping 231.mp4, already processed.
# Skipping 232.mp4, already processed.
# Skipping 233.mp4, already processed.
# Skipping 234.mp4, already processed.
# Skipping 235.mp4, already processed.
# Skipping 236.mp4, already processed.
# Skipping 237.mp4, already processed.
# Skipping 238.mp4, already processed.
# Skipping 239.mp4, already processed.
# Skipping 240.mp4, already processed.
# Skipping 241.mp4, already processed.
# Skipping 242.mp4, already processed.
# Skipping 243.mp4, already processed.
# Skipping 244.mp4, already processed.
# Skipping 245.mp4, already processed.
# Skipping 246.mp4, already processed.
# Skipping 247.mp4, already processed.
# Skipping 248.mp4, already processed.
# Skipping 249.mp4, already processed.
# Skipping 250.mp4, already processed.
# Skipping 251.mp4, already processed.
# Skipping 252.mp4, already processed.
# Skipping 253.mp4, already processed.
# Skipping 254.mp4, already processed.
# Skipping 255.mp4, already processed.
# Skipping 256.mp4, already processed.
# Skipping 257.mp4, already processed.
# Skipping 258.mp4, already processed.
# Skipping 259.mp4, already processed.
# Skipping 260.mp4, already processed.
# Skipping 261.mp4, already processed.
# Skipping 262.mp4, already processed.
# Skipping 263.mp4, already processed.
# Skipping 264.mp4, already processed.
# Skipping 265.mp4, already processed.
# Skipping 266.mp4, already processed.
# Skipping 267.mp4, already processed.
# Skipping 268.mp4, already processed.
# Skipping 269.mp4, already processed.
# Skipping 270.mp4, already processed.
# Skipping 271.mp4, already processed.
# Skipping 272.mp4, already processed.
# Skipping 273.mp4, already processed.
# Skipping 274.mp4, already processed.
# Skipping 275.mp4, already processed.
# Skipping 276.mp4, already processed.
# Skipping 277.mp4, already processed.
# Skipping 278.mp4, already processed.
# Skipping 279.mp4, already processed.
# Skipping 280.mp4, already processed.
# Skipping 281.mp4, already processed.
# Skipping 282.mp4, already processed.
# Skipping 283.mp4, already processed.
# Skipping 284.mp4, already processed.
# Skipping 285.mp4, already processed.
# Skipping 286.mp4, already processed.
# Skipping 287.mp4, already processed.
# Skipping 288.mp4, already processed.
# Skipping 289.mp4, already processed.
# Skipping 290.mp4, already processed.
# Skipping 291.mp4, already processed.
# Skipping 292.mp4, already processed.
# Skipping 293.mp4, already processed.
# Skipping 294.mp4, already processed.
# Skipping 295.mp4, already processed.
# Skipping 296.mp4, already processed.
# Skipping 297.mp4, already processed.
# Skipping 298.mp4, already processed.
# Skipping 299.mp4, already processed.
# Skipping 300.mp4, already processed.
# Skipping 301.mp4, already processed.
# Skipping 302.mp4, already processed.
# Skipping 303.mp4, already processed.
# Skipping 304.mp4, already processed.
# Skipping 305.mp4, already processed.
# Skipping 306.mp4, already processed.
# Skipping 307.mp4, already processed.
# Skipping 308.mp4, already processed.
# Skipping 309.mp4, already processed.
# Skipping 310.mp4, already processed.
# Skipping 311.mp4, already processed.
# Skipping 312.mp4, already processed.
# Skipping 313.mp4, already processed.
# Skipping 314.mp4, already processed.
# Skipping 315.mp4, already processed.
# Skipping 316.mp4, already processed.
# Skipping 317.mp4, already processed.
# Skipping 318.mp4, already processed.
# Skipping 319.mp4, already processed.
# Skipping 320.mp4, already processed.
# Skipping 321.mp4, already processed.
# Skipping 322.mp4, already processed.
# Skipping 323.mp4, already processed.
# Skipping 324.mp4, already processed.
# Skipping 325.mp4, already processed.
# Skipping 326.mp4, already processed.
# Skipping 327.mp4, already processed.
# Skipping 328.mp4, already processed.
# Skipping 329.mp4, already processed.
# Skipping 330.mp4, already processed.
# Skipping 331.mp4, already processed.
# Skipping 332.mp4, already processed.
# Skipping 333.mp4, already processed.
# Skipping 334.mp4, already processed.
# Skipping 335.mp4, already processed.
# Skipping 336.mp4, already processed.
# Skipping 337.mp4, already processed.
# Skipping 338.mp4, already processed.
# Skipping 339.mp4, already processed.
# Skipping 340.mp4, already processed.
# Skipping 341.mp4, already processed.
# Skipping 342.mp4, already processed.
# Skipping 343.mp4, already processed.
# Skipping 344.mp4, already processed.
# Skipping 345.mp4, already processed.
# Skipping 346.mp4, already processed.
# Skipping 347.mp4, already processed.
# Skipping 348.mp4, already processed.
# Skipping 349.mp4, already processed.
# Skipping 350.mp4, already processed.
# Skipping 351.mp4, already processed.
# Skipping 352.mp4, already processed.
# Skipping 353.mp4, already processed.
# Skipping 354.mp4, already processed.
# Skipping 355.mp4, already processed.
# Skipping 356.mp4, already processed.
# Skipping 357.mp4, already processed.
# Skipping 358.mp4, already processed.
# Skipping 359.mp4, already processed.
# Skipping 360.mp4, already processed.
# Skipping 361.mp4, already processed.
# Skipping 362.mp4, already processed.
# Skipping 363.mp4, already processed.
# Skipping 364.mp4, already processed.
# Skipping 365.mp4, already processed.
# Skipping 366.mp4, already processed.
# Skipping 367.mp4, already processed.
# Skipping 368.mp4, already processed.
# Skipping 369.mp4, already processed.
# Skipping 370.mp4, already processed.
# Skipping 371.mp4, already processed.
# Skipping 372.mp4, already processed.
# Skipping 373.mp4, already processed.
# Skipping 374.mp4, already processed.
# Skipping 375.mp4, already processed.
# Skipping 376.mp4, already processed.
# Skipping 377.mp4, already processed.
# Skipping 378.mp4, already processed.
# Skipping 379.mp4, already processed.
# Skipping 380.mp4, already processed.
# Skipping 381.mp4, already processed.
# Skipping 382.mp4, already processed.
# Skipping 383.mp4, already processed.
# Skipping 384.mp4, already processed.
# Skipping 385.mp4, already processed.
# Skipping 386.mp4, already processed.
# Skipping 387.mp4, already processed.
# Skipping 388.mp4, already processed.
# Skipping 389.mp4, already processed.
# Skipping 390.mp4, already processed.
# Skipping 391.mp4, already processed.
# Skipping 392.mp4, already processed.
# Skipping 393.mp4, already processed.
# Skipping 394.mp4, already processed.
# Skipping 395.mp4, already processed.
# Skipping 396.mp4, already processed.
# Skipping 397.mp4, already processed.
# Skipping 398.mp4, already processed.
# Skipping 399.mp4, already processed.
# Skipping 400.mp4, already processed.
# Skipping 401.mp4, already processed.
# Skipping 402.mp4, already processed.
# Skipping 403.mp4, already processed.
# Skipping 404.mp4, already processed.
# Skipping 405.mp4, already processed.
# Skipping 406.mp4, already processed.
# Skipping 407.mp4, already processed.
# Skipping 408.mp4, already processed.
# Skipping 409.mp4, already processed.
# Skipping 410.mp4, already processed.
# Skipping 411.mp4, already processed.
# Skipping 412.mp4, already processed.
# Skipping 413.mp4, already processed.
# Skipping 414.mp4, already processed.
# Skipping 415.mp4, already processed.
# Skipping 416.mp4, already processed.
# Skipping 417.mp4, already processed.
# Skipping 418.mp4, already processed.
# Skipping 419.mp4, already processed.
# Skipping 420.mp4, already processed.
# Skipping 421.mp4, already processed.
# Skipping 422.mp4, already processed.
# Skipping 423.mp4, already processed.
# Skipping 424.mp4, already processed.
# Skipping 425.mp4, already processed.
# Skipping 426.mp4, already processed.
# Skipping 427.mp4, already processed.
# Skipping 428.mp4, already processed.
# Skipping 429.mp4, already processed.
# Skipping 430.mp4, already processed.
# Skipping 431.mp4, already processed.
# Skipping 432.mp4, already processed.
# Skipping 433.mp4, already processed.
# Skipping 434.mp4, already processed.
# Skipping 435.mp4, already processed.
# Skipping 436.mp4, already processed.
# Skipping 437.mp4, already processed.
# Skipping 438.mp4, already processed.
# Skipping 439.mp4, already processed.
# Skipping 440.mp4, already processed.
# Skipping 441.mp4, already processed.
# Skipping 442.mp4, already processed.
# Skipping 443.mp4, already processed.
# Skipping 444.mp4, already processed.
# Skipping 445.mp4, already processed.
# Skipping 446.mp4, already processed.
# Skipping 447.mp4, already processed.
# Skipping 448.mp4, already processed.
# Skipping 449.mp4, already processed.
# Skipping 450.mp4, already processed.
# Skipping 451.mp4, already processed.
# Skipping 452.mp4, already processed.
# Skipping 453.mp4, already processed.
# Skipping 454.mp4, already processed.
# Skipping 455.mp4, already processed.
# Skipping 456.mp4, already processed.
# Skipping 457.mp4, already processed.
# Skipping 458.mp4, already processed.
# Skipping 459.mp4, already processed.
# Skipping 460.mp4, already processed.
# Skipping 461.mp4, already processed.
# Skipping 462.mp4, already processed.
# Skipping 463.mp4, already processed.
# Skipping 464.mp4, already processed.
# Skipping 465.mp4, already processed.
# Skipping 466.mp4, already processed.
# Skipping 467.mp4, already processed.
# Skipping 468.mp4, already processed.
# Skipping 469.mp4, already processed.
# Skipping 470.mp4, already processed.
# Skipping 471.mp4, already processed.
# Skipping 472.mp4, already processed.
# Skipping 473.mp4, already processed.
# Skipping 474.mp4, already processed.
# Skipping 475.mp4, already processed.
# Skipping 476.mp4, already processed.
# Skipping 477.mp4, already processed.
# Skipping 478.mp4, already processed.
# Skipping 479.mp4, already processed.
# Skipping 480.mp4, already processed.
# Skipping 481.mp4, already processed.
# Skipping 482.mp4, already processed.
# Skipping 483.mp4, already processed.
# Skipping 484.mp4, already processed.
# Skipping 485.mp4, already processed.
# Skipping 486.mp4, already processed.
# Skipping 487.mp4, already processed.
# Skipping 488.mp4, already processed.
# Skipping 489.mp4, already processed.
# Skipping 490.mp4, already processed.
# Skipping 491.mp4, already processed.
# Skipping 492.mp4, already processed.
# Skipping 493.mp4, already processed.
# Skipping 494.mp4, already processed.
# Skipping 495.mp4, already processed.
# Skipping 496.mp4, already processed.
# Skipping 497.mp4, already processed.
# Skipping 498.mp4, already processed.
# Skipping 499.mp4, already processed.
# Skipping 500.mp4, already processed.
# Skipping 501.mp4, already processed.
# Skipping 502.mp4, already processed.
# Skipping 503.mp4, already processed.
# Skipping 504.mp4, already processed.
# Skipping 505.mp4, already processed.
# Skipping 506.mp4, already processed.
# Skipping 507.mp4, already processed.
# Skipping 508.mp4, already processed.
# Skipping 509.mp4, already processed.
# Skipping 510.mp4, already processed.
# Skipping 511.mp4, already processed.
# Skipping 512.mp4, already processed.
# Skipping 513.mp4, already processed.
# Skipping 514.mp4, already processed.
# Skipping 515.mp4, already processed.
# Skipping 516.mp4, already processed.
# Skipping 517.mp4, already processed.
# Skipping 518.mp4, already processed.
# Skipping 519.mp4, already processed.
# Skipping 520.mp4, already processed.
# Skipping 521.mp4, already processed.
# Skipping 522.mp4, already processed.
# Skipping 523.mp4, already processed.
# Skipping 524.mp4, already processed.
# Skipping 525.mp4, already processed.
# Skipping 526.mp4, already processed.
# Skipping 527.mp4, already processed.
# Skipping 528.mp4, already processed.
# Skipping 529.mp4, already processed.
# Skipping 530.mp4, already processed.
# Skipping 531.mp4, already processed.
# Skipping 532.mp4, already processed.
# Skipping 533.mp4, already processed.
# Skipping 534.mp4, already processed.
# Skipping 535.mp4, already processed.
# Skipping 536.mp4, already processed.
# Skipping 537.mp4, already processed.
# Skipping 538.mp4, already processed.
# Skipping 539.mp4, already processed.
# Skipping 540.mp4, already processed.
# Skipping 541.mp4, already processed.
# Skipping 542.mp4, already processed.
# Skipping 543.mp4, already processed.
# Skipping 544.mp4, already processed.
# Skipping 545.mp4, already processed.
# Skipping 546.mp4, already processed.
# Skipping 547.mp4, already processed.
# Skipping 548.mp4, already processed.
# Skipping 549.mp4, already processed.
# Skipping 550.mp4, already processed.
# Skipping 551.mp4, already processed.
# Skipping 552.mp4, already processed.
# Skipping 553.mp4, already processed.
# Skipping 554.mp4, already processed.
# Skipping 555.mp4, already processed.
# Skipping 556.mp4, already processed.
# Skipping 557.mp4, already processed.
# Skipping 558.mp4, already processed.
# Skipping 559.mp4, already processed.
# Skipping 560.mp4, already processed.
# Skipping 561.mp4, already processed.
# Skipping 562.mp4, already processed.
# Skipping 563.mp4, already processed.
# Skipping 564.mp4, already processed.
# Skipping 565.mp4, already processed.
# Skipping 566.mp4, already processed.
# Skipping 567.mp4, already processed.
# Skipping 568.mp4, already processed.
# Skipping 569.mp4, already processed.
# Skipping 570.mp4, already processed.
# Skipping 571.mp4, already processed.
# Skipping 572.mp4, already processed.
# Skipping 573.mp4, already processed.
# Skipping 574.mp4, already processed.
# Skipping 575.mp4, already processed.
# Skipping 576.mp4, already processed.
# Skipping 577.mp4, already processed.
# Skipping 578.mp4, already processed.
# Skipping 579.mp4, already processed.
# Skipping 580.mp4, already processed.
# Skipping 581.mp4, already processed.
# Skipping 582.mp4, already processed.
# Skipping 583.mp4, already processed.
# Skipping 584.mp4, already processed.
# Skipping 585.mp4, already processed.
# Skipping 586.mp4, already processed.
# Skipping 587.mp4, already processed.
# Skipping 588.mp4, already processed.
# Skipping 589.mp4, already processed.
# Skipping 590.mp4, already processed.
# Skipping 591.mp4, already processed.
# Skipping 592.mp4, already processed.
# Skipping 593.mp4, already processed.
# Skipping 594.mp4, already processed.
# Skipping 595.mp4, already processed.
# Skipping 596.mp4, already processed.
# Skipping 597.mp4, already processed.
# Skipping 598.mp4, already processed.
# Skipping 599.mp4, already processed.
# Skipping 600.mp4, already processed.
# Skipping 601.mp4, already processed.
# Skipping 602.mp4, already processed.
# Skipping 603.mp4, already processed.
# Skipping 604.mp4, already processed.
# Skipping 605.mp4, already processed.
# Skipping 606.mp4, already processed.
# Skipping 607.mp4, already processed.
# Skipping 608.mp4, already processed.
# Skipping 609.mp4, already processed.
# Skipping 610.mp4, already processed.
# Skipping 611.mp4, already processed.
# Skipping 612.mp4, already processed.
# Skipping 613.mp4, already processed.
# Skipping 614.mp4, already processed.
# Skipping 615.mp4, already processed.
# Skipping 616.mp4, already processed.
# Skipping 617.mp4, already processed.
# Skipping 618.mp4, already processed.
# Skipping 619.mp4, already processed.
# Skipping 620.mp4, already processed.
# Skipping 621.mp4, already processed.
# Skipping 622.mp4, already processed.
# Skipping 623.mp4, already processed.
# Skipping 624.mp4, already processed.
# Skipping 625.mp4, already processed.
# Skipping 626.mp4, already processed.
# Skipping 627.mp4, already processed.
# Skipping 628.mp4, already processed.
# Skipping 629.mp4, already processed.
# Skipping 630.mp4, already processed.
# Skipping 631.mp4, already processed.
# Skipping 632.mp4, already processed.
# Skipping 633.mp4, already processed.
# Skipping 634.mp4, already processed.
# Skipping 635.mp4, already processed.
# Skipping 636.mp4, already processed.
# Skipping 637.mp4, already processed.
# Skipping 638.mp4, already processed.
# Skipping 639.mp4, already processed.
# Skipping 640.mp4, already processed.
# Skipping 641.mp4, already processed.
# Skipping 642.mp4, already processed.
# Skipping 643.mp4, already processed.
# Skipping 644.mp4, already processed.
# Skipping 645.mp4, already processed.
# Skipping 646.mp4, already processed.
# Skipping 647.mp4, already processed.
# Skipping 648.mp4, already processed.
# Skipping 649.mp4, already processed.
# Skipping 650.mp4, already processed.
# Skipping 651.mp4, already processed.
# Skipping 652.mp4, already processed.
# Skipping 653.mp4, already processed.
# Skipping 654.mp4, already processed.
# Skipping 655.mp4, already processed.
# Skipping 656.mp4, already processed.
# Skipping 657.mp4, already processed.
# Skipping 658.mp4, already processed.
# Skipping 659.mp4, already processed.
# Skipping 660.mp4, already processed.
# Skipping 661.mp4, already processed.
# Skipping 662.mp4, already processed.
# Skipping 663.mp4, already processed.
# Skipping 664.mp4, already processed.
# Skipping 665.mp4, already processed.
# Skipping 666.mp4, already processed.
# Skipping 667.mp4, already processed.
# Skipping 668.mp4, already processed.
# Skipping 669.mp4, already processed.
# Skipping 670.mp4, already processed.
# Skipping 671.mp4, already processed.
# Skipping 672.mp4, already processed.
# Skipping 673.mp4, already processed.
# Skipping 674.mp4, already processed.
# Skipping 675.mp4, already processed.
# Skipping 676.mp4, already processed.
# Skipping 677.mp4, already processed.
# Skipping 678.mp4, already processed.
# Skipping 679.mp4, already processed.
# Skipping 680.mp4, already processed.
# Skipping 681.mp4, already processed.
# Skipping 682.mp4, already processed.
# Skipping 683.mp4, already processed.
# Skipping 684.mp4, already processed.
# Skipping 685.mp4, already processed.
# Skipping 686.mp4, already processed.
# Skipping 687.mp4, already processed.
# Skipping 688.mp4, already processed.
# Skipping 689.mp4, already processed.
# Skipping 690.mp4, already processed.
# Skipping 691.mp4, already processed.
# Skipping 692.mp4, already processed.
# Skipping 693.mp4, already processed.
# Skipping 694.mp4, already processed.
# Skipping 695.mp4, already processed.
# Skipping 696.mp4, already processed.
# Skipping 697.mp4, already processed.
# Skipping 698.mp4, already processed.
# Skipping 699.mp4, already processed.
# Skipping 700.mp4, already processed.
# Skipping 701.mp4, already processed.
# Skipping 702.mp4, already processed.
# Skipping 703.mp4, already processed.
# Skipping 704.mp4, already processed.
# Skipping 705.mp4, already processed.
# Skipping 706.mp4, already processed.
# Skipping 707.mp4, already processed.
# Skipping 708.mp4, already processed.
# Skipping 709.mp4, already processed.
# Skipping 710.mp4, already processed.
# Skipping 711.mp4, already processed.
# Skipping 712.mp4, already processed.
# Skipping 713.mp4, already processed.
# Skipping 714.mp4, already processed.
# Skipping 715.mp4, already processed.
# Skipping 716.mp4, already processed.
# Skipping 717.mp4, already processed.
# Skipping 718.mp4, already processed.
# Skipping 719.mp4, already processed.
# Skipping 720.mp4, already processed.
# Skipping 721.mp4, already processed.
# Skipping 722.mp4, already processed.
# Skipping 723.mp4, already processed.
# Skipping 724.mp4, already processed.
# Skipping 725.mp4, already processed.
# Skipping 726.mp4, already processed.
# Skipping 727.mp4, already processed.
# Skipping 728.mp4, already processed.
# Skipping 729.mp4, already processed.
# Skipping 730.mp4, already processed.
# Skipping 731.mp4, already processed.
# Skipping 732.mp4, already processed.
# Skipping 733.mp4, already processed.
# Skipping 734.mp4, already processed.
# Skipping 735.mp4, already processed.
# Skipping 736.mp4, already processed.
# Skipping 737.mp4, already processed.
# Skipping 738.mp4, already processed.
# Skipping 739.mp4, already processed.
# Skipping 740.mp4, already processed.
# Skipping 741.mp4, already processed.
# Skipping 742.mp4, already processed.
# Skipping 743.mp4, already processed.
# Skipping 744.mp4, already processed.
# Skipping 745.mp4, already processed.
# Skipping 746.mp4, already processed.
# Skipping 747.mp4, already processed.
# Skipping 748.mp4, already processed.
# Skipping 749.mp4, already processed.
# Skipping 750.mp4, already processed.
# Skipping 751.mp4, already processed.
# Skipping 752.mp4, already processed.
# Skipping 753.mp4, already processed.
# Skipping 754.mp4, already processed.
# Skipping 755.mp4, already processed.
# Skipping 756.mp4, already processed.
# Skipping 757.mp4, already processed.
# Skipping 758.mp4, already processed.
# Skipping 759.mp4, already processed.
# Skipping 760.mp4, already processed.
# Skipping 761.mp4, already processed.
# Skipping 762.mp4, already processed.
# Skipping 763.mp4, already processed.
# Skipping 764.mp4, already processed.
# Skipping 765.mp4, already processed.
# Skipping 766.mp4, already processed.
# Skipping 767.mp4, already processed.
# Skipping 768.mp4, already processed.
# Skipping 769.mp4, already processed.
# Skipping 770.mp4, already processed.
# Skipping 771.mp4, already processed.
# Skipping 772.mp4, already processed.
# Skipping 773.mp4, already processed.
# Skipping 774.mp4, already processed.
# Skipping 775.mp4, already processed.
# Skipping 776.mp4, already processed.
# Skipping 777.mp4, already processed.
# Skipping 778.mp4, already processed.
# Skipping 779.mp4, already processed.
# Skipping 780.mp4, already processed.
# Skipping 781.mp4, already processed.
# Skipping 782.mp4, already processed.
# Skipping 783.mp4, already processed.
# Skipping 784.mp4, already processed.
# Skipping 785.mp4, already processed.
# Skipping 786.mp4, already processed.
# Skipping 787.mp4, already processed.
# Skipping 788.mp4, already processed.
# Skipping 789.mp4, already processed.
# Skipping 790.mp4, already processed.
# Skipping 791.mp4, already processed.
# Skipping 792.mp4, already processed.
# Skipping 793.mp4, already processed.
# Skipping 794.mp4, already processed.
# Skipping 795.mp4, already processed.
# Skipping 796.mp4, already processed.
# Skipping 797.mp4, already processed.
# Skipping 798.mp4, already processed.
# Skipping 799.mp4, already processed.
# Skipping 800.mp4, already processed.
# Skipping 801.mp4, already processed.
# Skipping 802.mp4, already processed.
# Skipping 803.mp4, already processed.
# Skipping 804.mp4, already processed.
# Skipping 805.mp4, already processed.
# Skipping 806.mp4, already processed.
# Skipping 807.mp4, already processed.
# Skipping 808.mp4, already processed.
# Skipping 809.mp4, already processed.
# Skipping 810.mp4, already processed.
# Skipping 811.mp4, already processed.
# Skipping 812.mp4, already processed.
# Skipping 813.mp4, already processed.
# Skipping 814.mp4, already processed.
# Skipping 815.mp4, already processed.
# Skipping 816.mp4, already processed.
# Skipping 817.mp4, already processed.
# Skipping 818.mp4, already processed.
# Skipping 819.mp4, already processed.
# Skipping 820.mp4, already processed.
# Skipping 821.mp4, already processed.
# Skipping 822.mp4, already processed.
# Skipping 823.mp4, already processed.
# Skipping 824.mp4, already processed.
# Skipping 825.mp4, already processed.
# Skipping 826.mp4, already processed.
# Skipping 827.mp4, already processed.
# Skipping 828.mp4, already processed.
# Skipping 829.mp4, already processed.
# Skipping 830.mp4, already processed.
# Skipping 831.mp4, already processed.
# Skipping 832.mp4, already processed.
# Skipping 833.mp4, already processed.
# Skipping 834.mp4, already processed.
# Skipping 835.mp4, already processed.
# Skipping 836.mp4, already processed.
# Skipping 837.mp4, already processed.
# Skipping 838.mp4, already processed.
# Skipping 839.mp4, already processed.
# Skipping 840.mp4, already processed.
# Skipping 841.mp4, already processed.
# Skipping 842.mp4, already processed.
# Skipping 843.mp4, already processed.
# Skipping 844.mp4, already processed.
# Skipping 845.mp4, already processed.
# Skipping 846.mp4, already processed.
# Skipping 847.mp4, already processed.
# Skipping 848.mp4, already processed.
# Skipping 849.mp4, already processed.
# Skipping 850.mp4, already processed.
# Skipping 851.mp4, already processed.
# Skipping 852.mp4, already processed.
# Skipping 853.mp4, already processed.
# Skipping 854.mp4, already processed.
# Skipping 855.mp4, already processed.
# Skipping 856.mp4, already processed.
# Skipping 857.mp4, already processed.
# Skipping 858.mp4, already processed.
# Skipping 859.mp4, already processed.
# Skipping 860.mp4, already processed.
# Skipping 861.mp4, already processed.
# Skipping 862.mp4, already processed.
# Skipping 863.mp4, already processed.
# Skipping 864.mp4, already processed.
# Skipping 865.mp4, already processed.
# Skipping 866.mp4, already processed.
# Skipping 867.mp4, already processed.
# Skipping 868.mp4, already processed.
# Skipping 869.mp4, already processed.
# Skipping 870.mp4, already processed.
# Skipping 871.mp4, already processed.
# Skipping 872.mp4, already processed.
# Skipping 873.mp4, already processed.
# Skipping 874.mp4, already processed.
# Skipping 875.mp4, already processed.
# Skipping 876.mp4, already processed.
# Skipping 877.mp4, already processed.
# Skipping 878.mp4, already processed.
# Skipping 879.mp4, already processed.
# Skipping 880.mp4, already processed.
# Skipping 881.mp4, already processed.
# Skipping 882.mp4, already processed.
# Skipping 883.mp4, already processed.
# Skipping 884.mp4, already processed.
# Skipping 885.mp4, already processed.
# Skipping 886.mp4, already processed.
# Skipping 887.mp4, already processed.
# Skipping 888.mp4, already processed.
# Skipping 889.mp4, already processed.
# Skipping 890.mp4, already processed.
# Skipping 891.mp4, already processed.
# Skipping 892.mp4, already processed.
# Skipping 893.mp4, already processed.
# Skipping 894.mp4, already processed.
# Skipping 895.mp4, already processed.
# Skipping 896.mp4, already processed.
# Skipping 897.mp4, already processed.
# Skipping 898.mp4, already processed.
# Skipping 899.mp4, already processed.
# Skipping 900.mp4, already processed.
# Skipping 901.mp4, already processed.
# Skipping 902.mp4, already processed.
# Skipping 903.mp4, already processed.
# Skipping 904.mp4, already processed.
# Skipping 905.mp4, already processed.
# Skipping 906.mp4, already processed.
# Skipping 907.mp4, already processed.
# Skipping 908.mp4, already processed.
# Skipping 909.mp4, already processed.
# Skipping 910.mp4, already processed.
# Skipping 911.mp4, already processed.
# Skipping 912.mp4, already processed.
# Skipping 913.mp4, already processed.
# Skipping 914.mp4, already processed.
# Skipping 915.mp4, already processed.
# Skipping 916.mp4, already processed.
# Skipping 917.mp4, already processed.
# Skipping 918.mp4, already processed.
# Skipping 919.mp4, already processed.
# Skipping 920.mp4, already processed.
# Skipping 921.mp4, already processed.
# Skipping 922.mp4, already processed.
# Skipping 923.mp4, already processed.
# Skipping 924.mp4, already processed.
# Skipping 925.mp4, already processed.
# Skipping 926.mp4, already processed.
# Skipping 927.mp4, already processed.
# Skipping 928.mp4, already processed.
# Skipping 929.mp4, already processed.
# Skipping 930.mp4, already processed.
# Skipping 931.mp4, already processed.
# Skipping 932.mp4, already processed.
# Skipping 933.mp4, already processed.
# Skipping 934.mp4, already processed.
# Skipping 935.mp4, already processed.
# Skipping 936.mp4, already processed.
# Skipping 937.mp4, already processed.
# Skipping 938.mp4, already processed.
# Skipping 939.mp4, already processed.
# Skipping 940.mp4, already processed.
# Skipping 941.mp4, already processed.
# Skipping 942.mp4, already processed.
# Skipping 943.mp4, already processed.
# Skipping 944.mp4, already processed.
# Skipping 945.mp4, already processed.
# Skipping 946.mp4, already processed.
# Skipping 947.mp4, already processed.
# Skipping 948.mp4, already processed.
# Skipping 949.mp4, already processed.
# Skipping 950.mp4, already processed.
# Skipping 951.mp4, already processed.
# Skipping 952.mp4, already processed.
# Skipping 953.mp4, already processed.
# Skipping 954.mp4, already processed.
# Skipping 955.mp4, already processed.
# Skipping 956.mp4, already processed.
# Skipping 957.mp4, already processed.
# Skipping 958.mp4, already processed.
# Skipping 959.mp4, already processed.
# Skipping 960.mp4, already processed.
# Skipping 961.mp4, already processed.
# Skipping 962.mp4, already processed.
# Skipping 963.mp4, already processed.
# Skipping 964.mp4, already processed.
# Skipping 965.mp4, already processed.
# Skipping 966.mp4, already processed.
# Skipping 967.mp4, already processed.
# Skipping 968.mp4, already processed.
# Skipping 969.mp4, already processed.
# Skipping 970.mp4, already processed.
# Skipping 971.mp4, already processed.
# Skipping 972.mp4, already processed.
# Skipping 973.mp4, already processed.
# Skipping 974.mp4, already processed.
# Skipping 975.mp4, already processed.
# Skipping 976.mp4, already processed.
# Skipping 977.mp4, already processed.
# Skipping 978.mp4, already processed.
# Skipping 979.mp4, already processed.
# Skipping 980.mp4, already processed.
# Skipping 981.mp4, already processed.
# Skipping 982.mp4, already processed.
# Skipping 983.mp4, already processed.
# Skipping 984.mp4, already processed.
# Skipping 985.mp4, already processed.
# Skipping 986.mp4, already processed.
# Skipping 987.mp4, already processed.
# Skipping 988.mp4, already processed.
# Skipping 989.mp4, already processed.
# Skipping 990.mp4, already processed.
# Skipping 991.mp4, already processed.
# Skipping 992.mp4, already processed.
# Skipping 993.mp4, already processed.
# Skipping 994.mp4, already processed.
# Skipping 995.mp4, already processed.
# Skipping 996.mp4, already processed.
# Skipping 997.mp4, already processed.
# Skipping 998.mp4, already processed.
# Skipping 999.mp4, already processed.
# Skipping 000_003.mp4, already processed.
# Skipping 001_870.mp4, already processed.
# Skipping 002_006.mp4, already processed.
# Skipping 003_000.mp4, already processed.
# Skipping 004_982.mp4, already processed.
# Skipping 005_010.mp4, already processed.
# Skipping 006_002.mp4, already processed.
# Skipping 007_132.mp4, already processed.
# Skipping 008_990.mp4, already processed.
# Skipping 009_027.mp4, already processed.
# Skipping 010_005.mp4, already processed.
# Skipping 011_805.mp4, already processed.
# Skipping 012_026.mp4, already processed.
# Skipping 013_883.mp4, already processed.
# Skipping 014_790.mp4, already processed.
# Skipping 015_919.mp4, already processed.
# Skipping 016_209.mp4, already processed.
# Skipping 017_803.mp4, already processed.
# Skipping 018_019.mp4, already processed.
# Skipping 019_018.mp4, already processed.
# Skipping 020_344.mp4, already processed.
# Skipping 021_312.mp4, already processed.
# Skipping 022_489.mp4, already processed.
# Skipping 023_923.mp4, already processed.
# Skipping 024_073.mp4, already processed.
# Skipping 025_067.mp4, already processed.
# Skipping 026_012.mp4, already processed.
# Skipping 027_009.mp4, already processed.
# Skipping 028_068.mp4, already processed.
# Skipping 029_048.mp4, already processed.
# Skipping 030_193.mp4, already processed.
# Skipping 031_163.mp4, already processed.
# Skipping 032_944.mp4, already processed.
# Skipping 033_097.mp4, already processed.
# Skipping 034_590.mp4, already processed.
# Skipping 035_036.mp4, already processed.
# Skipping 036_035.mp4, already processed.
# Skipping 037_072.mp4, already processed.
# Skipping 038_125.mp4, already processed.
# Skipping 039_058.mp4, already processed.
# Skipping 040_997.mp4, already processed.
# Skipping 041_063.mp4, already processed.
# Skipping 042_084.mp4, already processed.
# Skipping 043_110.mp4, already processed.
# Skipping 044_945.mp4, already processed.
# Skipping 045_889.mp4, already processed.
# Skipping 046_904.mp4, already processed.
# Skipping 047_862.mp4, already processed.
# Skipping 048_029.mp4, already processed.
# Skipping 049_946.mp4, already processed.
# Skipping 050_059.mp4, already processed.
# Skipping 051_332.mp4, already processed.
# Skipping 052_108.mp4, already processed.
# Skipping 053_095.mp4, already processed.
# Skipping 054_071.mp4, already processed.
# Skipping 055_147.mp4, already processed.
# Skipping 056_996.mp4, already processed.
# Skipping 057_070.mp4, already processed.
# Skipping 058_039.mp4, already processed.
# Skipping 059_050.mp4, already processed.
# Skipping 060_088.mp4, already processed.
# Skipping 061_080.mp4, already processed.
# Skipping 062_066.mp4, already processed.
# Skipping 063_041.mp4, already processed.
# Skipping 064_991.mp4, already processed.
# Skipping 065_089.mp4, already processed.
# Skipping 066_062.mp4, already processed.
# Skipping 067_025.mp4, already processed.
# Skipping 068_028.mp4, already processed.
# Skipping 069_961.mp4, already processed.
# Skipping 070_057.mp4, already processed.
# Skipping 071_054.mp4, already processed.
# Skipping 072_037.mp4, already processed.
# Skipping 073_024.mp4, already processed.
# Skipping 074_825.mp4, already processed.
# Skipping 075_977.mp4, already processed.
# Skipping 076_079.mp4, already processed.
# Skipping 077_100.mp4, already processed.
# Skipping 078_955.mp4, already processed.
# Skipping 079_076.mp4, already processed.
# Skipping 080_061.mp4, already processed.
# Skipping 081_087.mp4, already processed.
# Skipping 082_103.mp4, already processed.
# Skipping 083_213.mp4, already processed.
# Skipping 084_042.mp4, already processed.
# Skipping 085_124.mp4, already processed.
# Skipping 086_090.mp4, already processed.
# Skipping 087_081.mp4, already processed.
# Skipping 088_060.mp4, already processed.
# Skipping 089_065.mp4, already processed.
# Skipping 090_086.mp4, already processed.
# Skipping 091_116.mp4, already processed.
# Skipping 092_098.mp4, already processed.
# Skipping 093_121.mp4, already processed.
# Skipping 094_111.mp4, already processed.
# Skipping 095_053.mp4, already processed.
# Skipping 096_101.mp4, already processed.
# Skipping 097_033.mp4, already processed.
# Skipping 098_092.mp4, already processed.
# Skipping 099_295.mp4, already processed.
# Skipping 100_077.mp4, already processed.
# Skipping 101_096.mp4, already processed.
# Skipping 102_114.mp4, already processed.
# Skipping 103_082.mp4, already processed.
# Skipping 104_126.mp4, already processed.
# Skipping 105_180.mp4, already processed.
# Skipping 106_198.mp4, already processed.
# Skipping 107_109.mp4, already processed.
# Skipping 108_052.mp4, already processed.
# Skipping 109_107.mp4, already processed.
# Skipping 110_043.mp4, already processed.
# Skipping 111_094.mp4, already processed.
# Skipping 112_892.mp4, already processed.
# Skipping 113_983.mp4, already processed.
# Skipping 114_102.mp4, already processed.
# Skipping 115_939.mp4, already processed.
# Skipping 116_091.mp4, already processed.
# Skipping 117_217.mp4, already processed.
# Skipping 118_120.mp4, already processed.
# Skipping 119_123.mp4, already processed.
# Skipping 120_118.mp4, already processed.
# Skipping 121_093.mp4, already processed.
# Skipping 122_144.mp4, already processed.
# Skipping 123_119.mp4, already processed.
# Skipping 124_085.mp4, already processed.
# Skipping 125_038.mp4, already processed.
# Skipping 126_104.mp4, already processed.
# Skipping 127_129.mp4, already processed.
# Skipping 128_896.mp4, already processed.
# Skipping 129_127.mp4, already processed.
# Skipping 130_139.mp4, already processed.
# Skipping 131_518.mp4, already processed.
# Skipping 132_007.mp4, already processed.
# Skipping 133_148.mp4, already processed.
# Skipping 134_192.mp4, already processed.
# Skipping 135_880.mp4, already processed.
# Skipping 136_285.mp4, already processed.
# Skipping 137_165.mp4, already processed.
# Skipping 138_142.mp4, already processed.
# Skipping 139_130.mp4, already processed.
# Skipping 140_143.mp4, already processed.
# Skipping 141_161.mp4, already processed.
# Skipping 142_138.mp4, already processed.
# Skipping 143_140.mp4, already processed.
# Skipping 144_122.mp4, already processed.
# Skipping 145_299.mp4, already processed.
# Skipping 146_256.mp4, already processed.
# Skipping 147_055.mp4, already processed.
# Skipping 148_133.mp4, already processed.
# Skipping 149_152.mp4, already processed.
# Skipping 150_153.mp4, already processed.
# Skipping 151_225.mp4, already processed.
# Skipping 152_149.mp4, already processed.
# Skipping 153_150.mp4, already processed.
# Skipping 154_386.mp4, already processed.
# Skipping 155_576.mp4, already processed.
# Skipping 156_243.mp4, already processed.
# Skipping 157_245.mp4, already processed.
# Skipping 158_379.mp4, already processed.
# Skipping 159_175.mp4, already processed.
# Skipping 160_928.mp4, already processed.
# Skipping 161_141.mp4, already processed.
# Skipping 162_330.mp4, already processed.
# Skipping 163_031.mp4, already processed.
# Skipping 164_216.mp4, already processed.
# Skipping 165_137.mp4, already processed.
# Skipping 166_167.mp4, already processed.
# Skipping 167_166.mp4, already processed.
# Skipping 168_222.mp4, already processed.
# Skipping 169_227.mp4, already processed.
# Skipping 170_186.mp4, already processed.
# Skipping 171_173.mp4, already processed.
# Skipping 172_582.mp4, already processed.
# Skipping 173_171.mp4, already processed.
# Skipping 174_964.mp4, already processed.
# Skipping 175_159.mp4, already processed.
# Skipping 176_190.mp4, already processed.
# Skipping 177_211.mp4, already processed.
# Skipping 178_598.mp4, already processed.
# Skipping 179_212.mp4, already processed.
# Skipping 180_105.mp4, already processed.
# Skipping 181_199.mp4, already processed.
# Skipping 182_242.mp4, already processed.
# Skipping 183_253.mp4, already processed.
# Skipping 184_205.mp4, already processed.
# Skipping 185_276.mp4, already processed.
# Skipping 186_170.mp4, already processed.
# Skipping 187_234.mp4, already processed.
# Skipping 188_191.mp4, already processed.
# Skipping 189_200.mp4, already processed.
# Skipping 190_176.mp4, already processed.
# Skipping 191_188.mp4, already processed.
# Skipping 192_134.mp4, already processed.
# Skipping 193_030.mp4, already processed.
# Skipping 194_235.mp4, already processed.
# Skipping 195_442.mp4, already processed.
# Skipping 196_310.mp4, already processed.
# Skipping 197_224.mp4, already processed.
# Skipping 198_106.mp4, already processed.
# Skipping 199_181.mp4, already processed.
# Skipping 200_189.mp4, already processed.
# Skipping 201_203.mp4, already processed.
# Skipping 202_348.mp4, already processed.
# Skipping 203_201.mp4, already processed.
# Skipping 204_230.mp4, already processed.
# Skipping 205_184.mp4, already processed.
# Skipping 206_221.mp4, already processed.
# Skipping 207_908.mp4, already processed.
# Skipping 208_215.mp4, already processed.
# Skipping 209_016.mp4, already processed.
# Skipping 210_241.mp4, already processed.
# Skipping 211_177.mp4, already processed.
# Skipping 212_179.mp4, already processed.
# Skipping 213_083.mp4, already processed.
# Skipping 214_255.mp4, already processed.
# Skipping 215_208.mp4, already processed.
# Skipping 216_164.mp4, already processed.
# Skipping 217_117.mp4, already processed.
# Skipping 218_239.mp4, already processed.
# Skipping 219_220.mp4, already processed.
# Skipping 220_219.mp4, already processed.
# Skipping 221_206.mp4, already processed.
# Skipping 222_168.mp4, already processed.
# Skipping 223_586.mp4, already processed.
# Skipping 224_197.mp4, already processed.
# Skipping 225_151.mp4, already processed.
# Skipping 226_491.mp4, already processed.
# Skipping 227_169.mp4, already processed.
# Skipping 228_289.mp4, already processed.
# Skipping 229_247.mp4, already processed.
# Skipping 230_204.mp4, already processed.
# Skipping 231_663.mp4, already processed.
# Skipping 232_248.mp4, already processed.
# Skipping 233_995.mp4, already processed.
# Skipping 234_187.mp4, already processed.
# Skipping 235_194.mp4, already processed.
# Skipping 236_237.mp4, already processed.
# Skipping 237_236.mp4, already processed.
# Skipping 238_282.mp4, already processed.
# Skipping 239_218.mp4, already processed.
# Skipping 240_290.mp4, already processed.
# Skipping 241_210.mp4, already processed.
# Skipping 242_182.mp4, already processed.
# Skipping 243_156.mp4, already processed.
# Skipping 244_822.mp4, already processed.
# Skipping 245_157.mp4, already processed.
# Skipping 246_258.mp4, already processed.
# Skipping 247_229.mp4, already processed.
# Skipping 248_232.mp4, already processed.
# Skipping 249_280.mp4, already processed.
# Skipping 250_461.mp4, already processed.
# Skipping 251_375.mp4, already processed.
# Skipping 252_266.mp4, already processed.
# Skipping 253_183.mp4, already processed.
# Skipping 254_261.mp4, already processed.
# Skipping 255_214.mp4, already processed.
# Skipping 256_146.mp4, already processed.
# Skipping 257_420.mp4, already processed.
# Skipping 258_246.mp4, already processed.
# Skipping 259_345.mp4, already processed.
# Skipping 260_331.mp4, already processed.
# Skipping 261_254.mp4, already processed.
# Skipping 262_301.mp4, already processed.
# Skipping 263_284.mp4, already processed.
# Skipping 264_271.mp4, already processed.
# Skipping 265_475.mp4, already processed.
# Skipping 266_252.mp4, already processed.
# Skipping 267_286.mp4, already processed.
# ...
# Skipping 309_303.mp4, already processed.
# Skipping 310_196.mp4, already processed.
# Skipping 311_387.mp4, already processed.
# Skipping 312_021.mp4, already processed.
# Skipping 313_283.mp4, already processed.
# Skipping 314_347.mp4, already processed.
# Skipping 315_322.mp4, already processed.
# Skipping 316_369.mp4, already processed.
# Skipping 317_359.mp4, already processed.
# Skipping 318_334.mp4, already processed.
# Skipping 319_352.mp4, already processed.
# Skipping 320_328.mp4, already processed.
# Skipping 321_288.mp4, already processed.
# Skipping 322_315.mp4, already processed.
# Skipping 323_302.mp4, already processed.
# Skipping 324_356.mp4, already processed.
# Skipping 325_492.mp4, already processed.
# Skipping 326_501.mp4, already processed.
# Skipping 327_329.mp4, already processed.
# Skipping 328_320.mp4, already processed.
# Skipping 329_327.mp4, already processed.
# Skipping 330_162.mp4, already processed.
# Skipping 331_260.mp4, already processed.
# Skipping 332_051.mp4, already processed.
# Skipping 333_377.mp4, already processed.
# Skipping 334_318.mp4, already processed.
# Skipping 335_277.mp4, already processed.
# Skipping 336_338.mp4, already processed.
# Skipping 337_522.mp4, already processed.
# Skipping 338_336.mp4, already processed.
# Skipping 339_392.mp4, already processed.
# Skipping 340_341.mp4, already processed.
# Skipping 341_340.mp4, already processed.
# Skipping 342_416.mp4, already processed.
# Skipping 343_363.mp4, already processed.
# Skipping 344_020.mp4, already processed.
# Skipping 345_259.mp4, already processed.
# Skipping 346_351.mp4, already processed.
# Skipping 347_314.mp4, already processed.
# Skipping 348_202.mp4, already processed.
# Skipping 349_350.mp4, already processed.
# Skipping 350_349.mp4, already processed.
# Skipping 351_346.mp4, already processed.
# Skipping 352_319.mp4, already processed.
# Skipping 353_383.mp4, already processed.
# Skipping 354_362.mp4, already processed.
# Skipping 355_748.mp4, already processed.
# Skipping 356_324.mp4, already processed.
# Skipping 357_432.mp4, already processed.
# Skipping 358_380.mp4, already processed.
# Skipping 359_317.mp4, already processed.
# Skipping 360_437.mp4, already processed.
# Skipping 361_448.mp4, already processed.
# Skipping 362_354.mp4, already processed.
# Skipping 363_343.mp4, already processed.
# Skipping 364_440.mp4, already processed.
# Skipping 365_307.mp4, already processed.
# Skipping 366_473.mp4, already processed.
# Skipping 367_371.mp4, already processed.
# Skipping 368_378.mp4, already processed.
# Skipping 369_316.mp4, already processed.
# Skipping 370_483.mp4, already processed.
# Skipping 371_367.mp4, already processed.
# Skipping 372_413.mp4, already processed.
# Skipping 373_394.mp4, already processed.
# Skipping 374_407.mp4, already processed.
# Skipping 375_251.mp4, already processed.
# Skipping 376_381.mp4, already processed.
# Skipping 377_333.mp4, already processed.
# Skipping 378_368.mp4, already processed.
# Skipping 379_158.mp4, already processed.
# Skipping 380_358.mp4, already processed.
# Skipping 381_376.mp4, already processed.
# Skipping 382_409.mp4, already processed.
# Skipping 383_353.mp4, already processed.
# Skipping 384_932.mp4, already processed.
# Skipping 385_414.mp4, already processed.
# Skipping 386_154.mp4, already processed.
# Skipping 387_311.mp4, already processed.
# Skipping 388_308.mp4, already processed.
# Skipping 389_480.mp4, already processed.
# Skipping 390_709.mp4, already processed.
# Skipping 391_406.mp4, already processed.
# Skipping 392_339.mp4, already processed.
# Skipping 393_405.mp4, already processed.
# Skipping 394_373.mp4, already processed.
# Skipping 395_401.mp4, already processed.
# Skipping 396_272.mp4, already processed.
# Skipping 397_602.mp4, already processed.
# Skipping 398_457.mp4, already processed.
# Skipping 399_488.mp4, already processed.
# Skipping 400_476.mp4, already processed.
# Skipping 401_395.mp4, already processed.
# Skipping 402_453.mp4, already processed.
# Skipping 403_497.mp4, already processed.
# Skipping 404_429.mp4, already processed.
# Skipping 405_393.mp4, already processed.
# Skipping 406_391.mp4, already processed.
# Skipping 407_374.mp4, already processed.
# Skipping 408_424.mp4, already processed.
# Skipping 409_382.mp4, already processed.
# Skipping 410_411.mp4, already processed.
# Skipping 411_410.mp4, already processed.
# Skipping 412_274.mp4, already processed.
# Skipping 413_372.mp4, already processed.
# Skipping 414_385.mp4, already processed.
# Skipping 415_484.mp4, already processed.
# Skipping 416_342.mp4, already processed.
# Skipping 417_496.mp4, already processed.
# Skipping 418_507.mp4, already processed.
# Skipping 419_824.mp4, already processed.
# Skipping 420_257.mp4, already processed.
# Skipping 421_423.mp4, already processed.
# Skipping 422_695.mp4, already processed.
# Skipping 423_421.mp4, already processed.
# Skipping 424_408.mp4, already processed.
# Skipping 425_485.mp4, already processed.
# Skipping 426_287.mp4, already processed.
# Skipping 427_637.mp4, already processed.
# Skipping 428_466.mp4, already processed.
# Skipping 429_404.mp4, already processed.
# Skipping 430_459.mp4, already processed.
# Skipping 431_447.mp4, already processed.
# Skipping 432_357.mp4, already processed.
# Skipping 433_498.mp4, already processed.
# Skipping 434_438.mp4, already processed.
# Skipping 435_456.mp4, already processed.
# Skipping 436_526.mp4, already processed.
# Skipping 437_360.mp4, already processed.
# Skipping 438_434.mp4, already processed.
# Skipping 439_441.mp4, already processed.
# Skipping 440_364.mp4, already processed.
# Skipping 441_439.mp4, already processed.
# Skipping 442_195.mp4, already processed.
# Skipping 443_514.mp4, already processed.
# Skipping 444_655.mp4, already processed.
# Skipping 445_494.mp4, already processed.
# Skipping 446_667.mp4, already processed.
# Skipping 447_431.mp4, already processed.
# Skipping 448_361.mp4, already processed.
# Skipping 449_451.mp4, already processed.
# Skipping 450_533.mp4, already processed.
# Skipping 451_449.mp4, already processed.
# Skipping 452_550.mp4, already processed.
# Skipping 453_402.mp4, already processed.
# Skipping 454_527.mp4, already processed.
# Skipping 455_471.mp4, already processed.
# Skipping 456_435.mp4, already processed.
# Skipping 457_398.mp4, already processed.
# Skipping 458_722.mp4, already processed.
# Skipping 459_430.mp4, already processed.
# Skipping 460_678.mp4, already processed.
# Skipping 461_250.mp4, already processed.
# Skipping 462_467.mp4, already processed.
# Skipping 463_464.mp4, already processed.
# Skipping 464_463.mp4, already processed.
# Skipping 465_482.mp4, already processed.
# Skipping 466_428.mp4, already processed.
# Skipping 467_462.mp4, already processed.
# Skipping 468_470.mp4, already processed.
# Skipping 469_481.mp4, already processed.
# Skipping 470_468.mp4, already processed.
# Skipping 471_455.mp4, already processed.
# Skipping 472_511.mp4, already processed.
# Skipping 473_366.mp4, already processed.
# Skipping 474_281.mp4, already processed.
# Skipping 475_265.mp4, already processed.
# Skipping 476_400.mp4, already processed.
# Skipping 477_487.mp4, already processed.
# Skipping 478_506.mp4, already processed.
# Skipping 479_706.mp4, already processed.
# Skipping 480_389.mp4, already processed.
# Skipping 481_469.mp4, already processed.
# Skipping 482_465.mp4, already processed.
# Skipping 483_370.mp4, already processed.
# Skipping 484_415.mp4, already processed.
# Skipping 485_425.mp4, already processed.
# Skipping 486_680.mp4, already processed.
# Skipping 487_477.mp4, already processed.
# Skipping 488_399.mp4, already processed.
# Skipping 489_022.mp4, already processed.
# Skipping 490_534.mp4, already processed.
# Skipping 491_226.mp4, already processed.
# Skipping 492_325.mp4, already processed.
# Skipping 493_538.mp4, already processed.
# Skipping 494_445.mp4, already processed.
# Skipping 495_512.mp4, already processed.
# Skipping 496_417.mp4, already processed.
# Skipping 497_403.mp4, already processed.
# Skipping 498_433.mp4, already processed.
# Skipping 499_539.mp4, already processed.
# Skipping 500_592.mp4, already processed.
# Skipping 501_326.mp4, already processed.
# Skipping 502_504.mp4, already processed.
# Skipping 503_756.mp4, already processed.
# Skipping 504_502.mp4, already processed.
# Skipping 505_600.mp4, already processed.
# Skipping 506_478.mp4, already processed.
# Skipping 507_418.mp4, already processed.
# Skipping 508_831.mp4, already processed.
# Skipping 509_525.mp4, already processed.
# Skipping 510_528.mp4, already processed.
# Skipping 511_472.mp4, already processed.
# Skipping 512_495.mp4, already processed.
# Skipping 513_305.mp4, already processed.
# Skipping 514_443.mp4, already processed.
# Skipping 515_519.mp4, already processed.
# Skipping 516_555.mp4, already processed.
# Skipping 517_521.mp4, already processed.
# Skipping 518_131.mp4, already processed.
# Skipping 519_515.mp4, already processed.
# Skipping 520_542.mp4, already processed.
# Skipping 521_517.mp4, already processed.
# Skipping 522_337.mp4, already processed.
# Skipping 523_541.mp4, already processed.
# Skipping 524_580.mp4, already processed.
# Skipping 525_509.mp4, already processed.
# Skipping 526_436.mp4, already processed.
# Skipping 527_454.mp4, already processed.
# Skipping 528_510.mp4, already processed.
# Skipping 529_633.mp4, already processed.
# Skipping 530_594.mp4, already processed.
# Skipping 531_549.mp4, already processed.
# Skipping 532_544.mp4, already processed.
# Skipping 533_450.mp4, already processed.
# Skipping 534_490.mp4, already processed.
# Skipping 535_587.mp4, already processed.
# Skipping 536_540.mp4, already processed.
# Skipping 537_563.mp4, already processed.
# Skipping 538_493.mp4, already processed.
# Skipping 539_499.mp4, already processed.
# Skipping 540_536.mp4, already processed.
# Skipping 541_523.mp4, already processed.
# Skipping 542_520.mp4, already processed.
# Skipping 543_559.mp4, already processed.
# Skipping 544_532.mp4, already processed.
# Skipping 545_553.mp4, already processed.
# Skipping 546_621.mp4, already processed.
# Skipping 547_574.mp4, already processed.
# Skipping 548_632.mp4, already processed.
# Skipping 549_531.mp4, already processed.
# Skipping 550_452.mp4, already processed.
# Skipping 551_631.mp4, already processed.
# Skipping 552_851.mp4, already processed.
# Skipping 553_545.mp4, already processed.
# Skipping 554_572.mp4, already processed.
# Skipping 555_516.mp4, already processed.
# Skipping 556_588.mp4, already processed.
# Skipping 557_560.mp4, already processed.
# Skipping 558_583.mp4, already processed.
# Skipping 559_543.mp4, already processed.
# Skipping 560_557.mp4, already processed.
# Skipping 561_998.mp4, already processed.
# Skipping 562_626.mp4, already processed.
# Skipping 563_537.mp4, already processed.
# Skipping 564_971.mp4, already processed.
# Skipping 565_589.mp4, already processed.
# Skipping 566_617.mp4, already processed.
# Skipping 567_606.mp4, already processed.
# Skipping 568_628.mp4, already processed.
# Skipping 569_921.mp4, already processed.
# Skipping 570_624.mp4, already processed.
# Skipping 571_746.mp4, already processed.
# Skipping 572_554.mp4, already processed.
# Skipping 573_757.mp4, already processed.
# Skipping 574_547.mp4, already processed.
# Skipping 575_603.mp4, already processed.
# Skipping 576_155.mp4, already processed.
# Skipping 577_593.mp4, already processed.
# Skipping 578_636.mp4, already processed.
# Skipping 579_701.mp4, already processed.
# Skipping 580_524.mp4, already processed.
# Skipping 581_697.mp4, already processed.
# Skipping 582_172.mp4, already processed.
# Skipping 583_558.mp4, already processed.
# Skipping 584_823.mp4, already processed.
# Skipping 585_599.mp4, already processed.
# Skipping 586_223.mp4, already processed.
# Skipping 587_535.mp4, already processed.
# Skipping 588_556.mp4, already processed.
# Skipping 589_565.mp4, already processed.
# Skipping 590_034.mp4, already processed.
# Skipping 591_605.mp4, already processed.
# Skipping 592_500.mp4, already processed.
# Skipping 593_577.mp4, already processed.
# Skipping 594_530.mp4, already processed.
# Skipping 595_597.mp4, already processed.
# Skipping 596_609.mp4, already processed.
# Skipping 597_595.mp4, already processed.
# Skipping 598_178.mp4, already processed.
# Skipping 599_585.mp4, already processed.
# Skipping 600_505.mp4, already processed.
# Skipping 601_653.mp4, already processed.
# Skipping 602_397.mp4, already processed.
# Skipping 603_575.mp4, already processed.
# Skipping 604_703.mp4, already processed.
# Skipping 605_591.mp4, already processed.
# Skipping 606_567.mp4, already processed.
# Skipping 607_683.mp4, already processed.
# Skipping 608_675.mp4, already processed.
# Skipping 609_596.mp4, already processed.
# Skipping 610_692.mp4, already processed.
# Skipping 611_760.mp4, already processed.
# Skipping 612_702.mp4, already processed.
# Skipping 613_685.mp4, already processed.
# Skipping 614_616.mp4, already processed.
# Skipping 615_687.mp4, already processed.
# Skipping 616_614.mp4, already processed.
# Skipping 617_566.mp4, already processed.
# Skipping 618_629.mp4, already processed.
# Skipping 619_620.mp4, already processed.
# Skipping 620_619.mp4, already processed.
# Skipping 621_546.mp4, already processed.
# Skipping 622_647.mp4, already processed.
# Skipping 623_630.mp4, already processed.
# Skipping 624_570.mp4, already processed.
# Skipping 625_650.mp4, already processed.
# Skipping 626_562.mp4, already processed.
# Skipping 627_658.mp4, already processed.
# Skipping 628_568.mp4, already processed.
# Skipping 629_618.mp4, already processed.
# Skipping 630_623.mp4, already processed.
# Skipping 631_551.mp4, already processed.
# Skipping 632_548.mp4, already processed.
# Skipping 633_529.mp4, already processed.
# Skipping 634_660.mp4, already processed.
# Skipping 635_642.mp4, already processed.
# Skipping 636_578.mp4, already processed.
# Skipping 637_427.mp4, already processed.
# Skipping 638_640.mp4, already processed.
# Skipping 639_841.mp4, already processed.
# Skipping 640_638.mp4, already processed.
# Skipping 641_662.mp4, already processed.
# Skipping 642_635.mp4, already processed.
# Skipping 643_646.mp4, already processed.
# Skipping 644_657.mp4, already processed.
# Skipping 645_688.mp4, already processed.
# Skipping 646_643.mp4, already processed.
# Skipping 647_622.mp4, already processed.
# Skipping 648_654.mp4, already processed.
# Skipping 649_816.mp4, already processed.
# Skipping 650_625.mp4, already processed.
# Skipping 651_835.mp4, already processed.
# Skipping 652_773.mp4, already processed.
# Skipping 653_601.mp4, already processed.
# Skipping 654_648.mp4, already processed.
# Skipping 655_444.mp4, already processed.
# Skipping 656_666.mp4, already processed.
# Skipping 657_644.mp4, already processed.
# Skipping 658_627.mp4, already processed.
# Skipping 659_749.mp4, already processed.
# Skipping 660_634.mp4, already processed.
# Skipping 661_670.mp4, already processed.
# Skipping 662_641.mp4, already processed.
# Skipping 663_231.mp4, already processed.
# Skipping 664_668.mp4, already processed.
# Skipping 665_679.mp4, already processed.
# Skipping 666_656.mp4, already processed.
# Skipping 667_446.mp4, already processed.
# Skipping 668_664.mp4, already processed.
# Skipping 669_682.mp4, already processed.
# Skipping 670_661.mp4, already processed.
# Skipping 671_677.mp4, already processed.
# Skipping 672_720.mp4, already processed.
# Skipping 673_728.mp4, already processed.
# Skipping 674_744.mp4, already processed.
# Skipping 675_608.mp4, already processed.
# Skipping 676_776.mp4, already processed.
# Skipping 677_671.mp4, already processed.
# Skipping 678_460.mp4, already processed.
# Skipping 679_665.mp4, already processed.
# Skipping 680_486.mp4, already processed.
# Skipping 681_711.mp4, already processed.
# Skipping 682_669.mp4, already processed.
# Skipping 683_607.mp4, already processed.
# Skipping 684_717.mp4, already processed.
# Skipping 685_613.mp4, already processed.
# Skipping 686_696.mp4, already processed.
# Skipping 687_615.mp4, already processed.
# Skipping 688_645.mp4, already processed.
# Skipping 689_690.mp4, already processed.
# Skipping 690_689.mp4, already processed.
# Skipping 691_732.mp4, already processed.
# Skipping 692_610.mp4, already processed.
# Skipping 693_698.mp4, already processed.
# Skipping 694_767.mp4, already processed.
# Skipping 695_422.mp4, already processed.
# Skipping 696_686.mp4, already processed.
# Skipping 697_581.mp4, already processed.
# Dataset updated and saved as video_frames.csv.

# %%
import cv2
import numpy as np
import os
import csv

# Function to extract key frames from each video
def extract_key_frames(video_path, num_frames=10):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    key_frames = []
    
    last_frame = None
    diffs = []

    # Calculate differences between consecutive frames
    for i in range(total_frames):
        ret, frame = cap.read()
        if not ret:
            break
        if last_frame is not None:
            # Compute the difference between the current frame and the last frame
            diff = cv2.absdiff(frame, last_frame)
            diff_sum = np.sum(diff)
            diffs.append((diff_sum, i))
        last_frame = frame

    # Sort frames by the largest differences and select key frames
    diffs.sort(reverse=True, key=lambda x: x[0])
    key_frame_indices = [index for _, index in diffs[:num_frames]]
    key_frame_indices.sort()  # Sort in order of appearance

    # Extract key frames
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # Reset to start
    for i in range(total_frames):
        ret, frame = cap.read()
        if i in key_frame_indices and ret:
            key_frames.append(frame)
    
    cap.release()
    return key_frames

# Function to create dataset with key frames and labels, skipping already processed videos
def create_dataset(folders, output_dir, num_frames=10):
    dataset = []
    csv_file = os.path.join(output_dir, 'dataset.csv')

    # Read existing CSV if available to skip processed files
    processed_files = set()
    if os.path.exists(csv_file):
        with open(csv_file, 'r') as f:
            reader = csv.reader(f)
            next(reader)  # Skip header
            processed_files = {row[0].split('_key_frame_')[0] for row in reader}  # Updated split

    for folder, label in folders:
        for video_file in os.listdir(folder):
            video_path = os.path.join(folder, video_file)
            base_filename = os.path.splitext(video_file)[0]
            
            # Skip videos that are already processed
            if base_filename in processed_files:
                print(f"Skipping {video_file}, already processed.")
                continue
            
            key_frames = extract_key_frames(video_path, num_frames)
            for i, frame in enumerate(key_frames):
                frame_filename = f"{base_filename}_key_frame_{i}.jpg"
                frame_path = os.path.join(output_dir, frame_filename)
                cv2.imwrite(frame_path, frame)
                dataset.append((frame_path, label))
            
            # Write frames to the CSV after each video is processed
            with open(csv_file, 'a', newline='') as f:
                writer = csv.writer(f)
                if not processed_files:  # Write header only once if CSV is new
                    writer.writerow(["frame_path", "label"])
                writer.writerows([(f"{base_filename}_key_frame_{i}.jpg", label) for i in range(len(key_frames))])

    return dataset

# Define your video folders and corresponding labels
folders = [
    ('F:/Project/Dataset/Dataset/original_sequences/youtube/c40/videos', 'real'),
    ('F:/Project/Dataset/Dataset/manipulated_sequences/Deepfakes/c40/videos', 'fake')
]

# Define output directory for frames
output_dir = 'frames_dataset2'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Create the dataset
dataset = create_dataset(folders, output_dir)

print(f"Dataset updated and saved.")
# Out:
# Skipping 000.mp4, already processed.
# Skipping 001.mp4, already processed.
# Skipping 002.mp4, already processed.
# Skipping 003.mp4, already processed.
# Skipping 004.mp4, already processed.
# Skipping 005.mp4, already processed.
# Skipping 006.mp4, already processed.
# Skipping 007.mp4, already processed.
# Skipping 008.mp4, already processed.
# Skipping 009.mp4, already processed.
# Skipping 010.mp4, already processed.
# Skipping 011.mp4, already processed.
# Skipping 012.mp4, already processed.
# Skipping 013.mp4, already processed.
# Skipping 014.mp4, already processed.
# Skipping 015.mp4, already processed.
# Skipping 016.mp4, already processed.
# Skipping 017.mp4, already processed.
# Skipping 018.mp4, already processed.
# Skipping 019.mp4, already processed.
# Skipping 020.mp4, already processed.
# Skipping 021.mp4, already processed.
# Skipping 022.mp4, already processed.
# Skipping 023.mp4, already processed.
# Skipping 024.mp4, already processed.
# Skipping 025.mp4, already processed.
# Skipping 026.mp4, already processed.
# Skipping 027.mp4, already processed.
# Skipping 028.mp4, already processed.
# Skipping 029.mp4, already processed.
# Skipping 030.mp4, already processed.
# Skipping 031.mp4, already processed.
# Skipping 032.mp4, already processed.
# Skipping 033.mp4, already processed.
# Skipping 034.mp4, already processed.
# Skipping 035.mp4, already processed.
# Skipping 036.mp4, already processed.
# Skipping 037.mp4, already processed.
# Skipping 038.mp4, already processed.
# Skipping 039.mp4, already processed.
# Skipping 040.mp4, already processed.
# Skipping 041.mp4, already processed.
# Skipping 042.mp4, already processed.
# Skipping 043.mp4, already processed.
# Skipping 044.mp4, already processed.
# Skipping 045.mp4, already processed.
# Skipping 046.mp4, already processed.
# Skipping 047.mp4, already processed.
# Skipping 048.mp4, already processed.
# Skipping 049.mp4, already processed.
# Skipping 050.mp4, already processed.
# Skipping 051.mp4, already processed.
# Skipping 052.mp4, already processed.
# Skipping 053.mp4, already processed.
# Skipping 054.mp4, already processed.
# Skipping 055.mp4, already processed.
# Skipping 056.mp4, already processed.
# Skipping 057.mp4, already processed.
# Skipping 058.mp4, already processed.
# Skipping 059.mp4, already processed.
# Skipping 060.mp4, already processed.
# Skipping 061.mp4, already processed.
# Skipping 062.mp4, already processed.
# Skipping 063.mp4, already processed.
# Skipping 064.mp4, already processed.
# Skipping 065.mp4, already processed.
# Skipping 066.mp4, already processed.
# Skipping 067.mp4, already processed.
# Skipping 068.mp4, already processed.
# Skipping 069.mp4, already processed.
# Skipping 070.mp4, already processed.
# Skipping 071.mp4, already processed.
# Skipping 072.mp4, already processed.
# Skipping 073.mp4, already processed.
# Skipping 074.mp4, already processed.
# Skipping 075.mp4, already processed.
# Skipping 076.mp4, already processed.
# Skipping 077.mp4, already processed.
# Skipping 078.mp4, already processed.
# Skipping 079.mp4, already processed.
# Skipping 080.mp4, already processed.
# Skipping 081.mp4, already processed.
# Skipping 082.mp4, already processed.
# Skipping 083.mp4, already processed.
# Skipping 084.mp4, already processed.
# Skipping 085.mp4, already processed.
# Skipping 086.mp4, already processed.
# Skipping 087.mp4, already processed.
# Skipping 088.mp4, already processed.
# Skipping 089.mp4, already processed.
# Skipping 090.mp4, already processed.
# Skipping 091.mp4, already processed.
# Skipping 092.mp4, already processed.
# Skipping 093.mp4, already processed.
# Skipping 094.mp4, already processed.
# Skipping 095.mp4, already processed.
# Skipping 096.mp4, already processed.
# Skipping 097.mp4, already processed.
# Skipping 098.mp4, already processed.
# Skipping 099.mp4, already processed.
# Skipping 100.mp4, already processed.
# Skipping 101.mp4, already processed.
# Skipping 102.mp4, already processed.
# Skipping 103.mp4, already processed.
# Skipping 104.mp4, already processed.
# Skipping 105.mp4, already processed.
# Skipping 106.mp4, already processed.
# Skipping 107.mp4, already processed.
# Skipping 108.mp4, already processed.
# Skipping 109.mp4, already processed.
# Skipping 110.mp4, already processed.
# Skipping 111.mp4, already processed.
# Skipping 112.mp4, already processed.
# Skipping 113.mp4, already processed.
# Skipping 114.mp4, already processed.
# Skipping 115.mp4, already processed.
# Skipping 116.mp4, already processed.
# Skipping 117.mp4, already processed.
# Skipping 118.mp4, already processed.
# Skipping 119.mp4, already processed.
# Skipping 120.mp4, already processed.
# Skipping 121.mp4, already processed.
# Skipping 122.mp4, already processed.
# Skipping 123.mp4, already processed.
# Skipping 124.mp4, already processed.
# Skipping 125.mp4, already processed.
# Skipping 126.mp4, already processed.
# Skipping 127.mp4, already processed.
# Skipping 128.mp4, already processed.
# Skipping 129.mp4, already processed.
# Skipping 130.mp4, already processed.
# Skipping 131.mp4, already processed.
# Skipping 132.mp4, already processed.
# Skipping 133.mp4, already processed.
# Skipping 134.mp4, already processed.
# Skipping 135.mp4, already processed.
# Skipping 136.mp4, already processed.
# Skipping 137.mp4, already processed.
# Skipping 138.mp4, already processed.
# Skipping 139.mp4, already processed.
# Skipping 140.mp4, already processed.
# Skipping 141.mp4, already processed.
# Skipping 142.mp4, already processed.
# Skipping 143.mp4, already processed.
# Skipping 144.mp4, already processed.
# Skipping 145.mp4, already processed.
# Skipping 146.mp4, already processed.
# Skipping 147.mp4, already processed.
# Skipping 148.mp4, already processed.
# Skipping 149.mp4, already processed.
# Skipping 150.mp4, already processed.
# Skipping 151.mp4, already processed.
# Skipping 152.mp4, already processed.
# Skipping 153.mp4, already processed.
# Skipping 154.mp4, already processed.
# Skipping 155.mp4, already processed.
# Skipping 156.mp4, already processed.
# Skipping 157.mp4, already processed.
# Skipping 158.mp4, already processed.
# Skipping 159.mp4, already processed.
# Skipping 160.mp4, already processed.
# Skipping 161.mp4, already processed.
# Skipping 162.mp4, already processed.
# Skipping 163.mp4, already processed.
# Skipping 164.mp4, already processed.
# Skipping 165.mp4, already processed.
# Skipping 166.mp4, already processed.
# Skipping 167.mp4, already processed.
# Skipping 168.mp4, already processed.
# Skipping 169.mp4, already processed.
# Skipping 170.mp4, already processed.
# Skipping 171.mp4, already processed.
# Skipping 172.mp4, already processed.
# Skipping 173.mp4, already processed.
# Skipping 174.mp4, already processed.
# Skipping 175.mp4, already processed.
# Skipping 176.mp4, already processed.
# Skipping 177.mp4, already processed.
# Skipping 178.mp4, already processed.
# Skipping 179.mp4, already processed.
# Skipping 180.mp4, already processed.
# Skipping 181.mp4, already processed.
# Skipping 182.mp4, already processed.
# Skipping 183.mp4, already processed.
# Skipping 184.mp4, already processed.
# Skipping 185.mp4, already processed.
# Skipping 186.mp4, already processed.
# Skipping 187.mp4, already processed.
# Skipping 188.mp4, already processed.
# Skipping 189.mp4, already processed.
# Skipping 190.mp4, already processed.
# Skipping 191.mp4, already processed.
# Skipping 192.mp4, already processed.
# Skipping 193.mp4, already processed.
# Skipping 194.mp4, already processed.
# Skipping 195.mp4, already processed.
# Skipping 196.mp4, already processed.
# Skipping 197.mp4, already processed.
# Skipping 198.mp4, already processed.
# Skipping 199.mp4, already processed.
# Skipping 200.mp4, already processed.
# Skipping 201.mp4, already processed.
# Skipping 202.mp4, already processed.
# Skipping 203.mp4, already processed.
# Skipping 204.mp4, already processed.
# Skipping 205.mp4, already processed.
# Skipping 206.mp4, already processed.
# Skipping 207.mp4, already processed.
# Skipping 208.mp4, already processed.
# Skipping 209.mp4, already processed.
# Skipping 210.mp4, already processed.
# Skipping 211.mp4, already processed.
# Skipping 212.mp4, already processed.
# Skipping 213.mp4, already processed.
# Skipping 214.mp4, already processed.
# Skipping 215.mp4, already processed.
# Skipping 216.mp4, already processed.
# Skipping 217.mp4, already processed.
# Skipping 218.mp4, already processed.
# Skipping 219.mp4, already processed.
# Skipping 220.mp4, already processed.
# Skipping 221.mp4, already processed.
# Skipping 222.mp4, already processed.
# Skipping 223.mp4, already processed.
# Skipping 224.mp4, already processed.
# Skipping 225.mp4, already processed.
# Skipping 226.mp4, already processed.
# Skipping 227.mp4, already processed.
# Skipping 228.mp4, already processed.
# Skipping 229.mp4, already processed.
# Skipping 230.mp4, already processed.
# Skipping 231.mp4, already processed.
# Skipping 232.mp4, already processed.
# Skipping 233.mp4, already processed.
# Skipping 234.mp4, already processed.
# Skipping 235.mp4, already processed.
# Skipping 236.mp4, already processed.
# Skipping 237.mp4, already processed.
# Skipping 238.mp4, already processed.
# Skipping 239.mp4, already processed.
# Skipping 240.mp4, already processed.
# Skipping 241.mp4, already processed.
# Skipping 242.mp4, already processed.
# Skipping 243.mp4, already processed.
# Skipping 244.mp4, already processed.
# Skipping 245.mp4, already processed.
# Skipping 246.mp4, already processed.
# Skipping 247.mp4, already processed.
# Skipping 248.mp4, already processed.
# Skipping 249.mp4, already processed.
# Skipping 250.mp4, already processed.
# Skipping 251.mp4, already processed.
# Skipping 252.mp4, already processed.
# Skipping 253.mp4, already processed.
# Skipping 254.mp4, already processed.
# Skipping 255.mp4, already processed.
# Skipping 256.mp4, already processed.
# Skipping 257.mp4, already processed.
# Skipping 258.mp4, already processed.
# Skipping 259.mp4, already processed.
# Skipping 260.mp4, already processed.
# Skipping 261.mp4, already processed.
# Skipping 262.mp4, already processed.
# Skipping 263.mp4, already processed.
# Skipping 264.mp4, already processed.
# Skipping 265.mp4, already processed.
# Skipping 266.mp4, already processed.
# Skipping 267.mp4, already processed.
# Skipping 268.mp4, already processed.
# Skipping 269.mp4, already processed.
# Skipping 270.mp4, already processed.
# Skipping 271.mp4, already processed.
# Skipping 272.mp4, already processed.
# Skipping 273.mp4, already processed.
# Skipping 274.mp4, already processed.
# Skipping 275.mp4, already processed.
# Skipping 276.mp4, already processed.
# Skipping 277.mp4, already processed.
# Skipping 278.mp4, already processed.
# Skipping 279.mp4, already processed.
# Skipping 280.mp4, already processed.
# Skipping 281.mp4, already processed.
# Skipping 282.mp4, already processed.
# Skipping 283.mp4, already processed.
# Skipping 284.mp4, already processed.
# Skipping 285.mp4, already processed.
# Skipping 286.mp4, already processed.
# Skipping 287.mp4, already processed.
# Skipping 288.mp4, already processed.
# Skipping 289.mp4, already processed.
# Skipping 290.mp4, already processed.
# Skipping 291.mp4, already processed.
# Skipping 292.mp4, already processed.
# Skipping 293.mp4, already processed.
# Skipping 294.mp4, already processed.
# Skipping 295.mp4, already processed.
# Skipping 296.mp4, already processed.
# Skipping 297.mp4, already processed.
# Skipping 298.mp4, already processed.
# Skipping 299.mp4, already processed.
# Skipping 300.mp4, already processed.
# Skipping 301.mp4, already processed.
# Skipping 302.mp4, already processed.
# Skipping 303.mp4, already processed.
# Skipping 304.mp4, already processed.
# Skipping 305.mp4, already processed.
# Skipping 306.mp4, already processed.
# Skipping 307.mp4, already processed.
# Skipping 308.mp4, already processed.
# Skipping 309.mp4, already processed.
# Skipping 310.mp4, already processed.
# Skipping 311.mp4, already processed.
# Skipping 312.mp4, already processed.
# Skipping 313.mp4, already processed.
# Skipping 314.mp4, already processed.
# Skipping 315.mp4, already processed.
# Skipping 316.mp4, already processed.
# Skipping 317.mp4, already processed.
# Skipping 318.mp4, already processed.
# Skipping 319.mp4, already processed.
# Skipping 320.mp4, already processed.
# Skipping 321.mp4, already processed.
# Skipping 322.mp4, already processed.
# Skipping 323.mp4, already processed.
# Skipping 324.mp4, already processed.
# Skipping 325.mp4, already processed.
# Skipping 326.mp4, already processed.
# Skipping 327.mp4, already processed.
# Skipping 328.mp4, already processed.
# Skipping 329.mp4, already processed.
# Skipping 330.mp4, already processed.
# Skipping 331.mp4, already processed.
# Skipping 332.mp4, already processed.
# Skipping 333.mp4, already processed.
# Skipping 334.mp4, already processed.
# Skipping 335.mp4, already processed.
# Skipping 336.mp4, already processed.
# Skipping 337.mp4, already processed.
# Skipping 338.mp4, already processed.
# Skipping 339.mp4, already processed.
# Skipping 340.mp4, already processed.
# Skipping 341.mp4, already processed.
# Skipping 342.mp4, already processed.
# Skipping 343.mp4, already processed.
# Skipping 344.mp4, already processed.
# Skipping 345.mp4, already processed.
# Skipping 346.mp4, already processed.
# Skipping 347.mp4, already processed.
# Skipping 348.mp4, already processed.
# Skipping 349.mp4, already processed.
# Skipping 350.mp4, already processed.
# Skipping 351.mp4, already processed.
# Skipping 352.mp4, already processed.
# Skipping 353.mp4, already processed.
# Skipping 354.mp4, already processed.
# Skipping 355.mp4, already processed.
# Skipping 356.mp4, already processed.
# Skipping 357.mp4, already processed.
# Skipping 358.mp4, already processed.
# Skipping 359.mp4, already processed.
# Skipping 360.mp4, already processed.
# Skipping 361.mp4, already processed.
# Skipping 362.mp4, already processed.
# Skipping 363.mp4, already processed.
# Skipping 364.mp4, already processed.
# Skipping 365.mp4, already processed.
# Skipping 366.mp4, already processed.
# Skipping 367.mp4, already processed.
# Skipping 368.mp4, already processed.
# Skipping 369.mp4, already processed.
# Skipping 370.mp4, already processed.
# Skipping 371.mp4, already processed.
# Skipping 372.mp4, already processed.
# Skipping 373.mp4, already processed.
# Skipping 374.mp4, already processed.
# Skipping 375.mp4, already processed.
# Skipping 376.mp4, already processed.
# Skipping 377.mp4, already processed.
# Skipping 378.mp4, already processed.
# Skipping 379.mp4, already processed.
# Skipping 380.mp4, already processed.
# Skipping 381.mp4, already processed.
# Skipping 382.mp4, already processed.
# Skipping 383.mp4, already processed.
# Skipping 384.mp4, already processed.
# Skipping 385.mp4, already processed.
# Skipping 386.mp4, already processed.
# Skipping 387.mp4, already processed.
# Skipping 388.mp4, already processed.
# Skipping 389.mp4, already processed.
# Skipping 390.mp4, already processed.
# Skipping 391.mp4, already processed.
# Skipping 392.mp4, already processed.
# Skipping 393.mp4, already processed.
# Skipping 394.mp4, already processed.
# Skipping 395.mp4, already processed.
# Skipping 396.mp4, already processed.
# Skipping 397.mp4, already processed.
# Skipping 398.mp4, already processed.
# Skipping 399.mp4, already processed.
# Skipping 400.mp4, already processed.
# Skipping 401.mp4, already processed.
# Skipping 402.mp4, already processed.
# Skipping 403.mp4, already processed.
# Skipping 404.mp4, already processed.
# Skipping 405.mp4, already processed.
# Skipping 406.mp4, already processed.
# Skipping 407.mp4, already processed.
# Skipping 408.mp4, already processed.
# Skipping 409.mp4, already processed.
# Skipping 410.mp4, already processed.
# Skipping 411.mp4, already processed.
# Skipping 412.mp4, already processed.
# Skipping 413.mp4, already processed.
# Skipping 414.mp4, already processed.
# Skipping 415.mp4, already processed.
# Skipping 416.mp4, already processed.
# Skipping 417.mp4, already processed.
# Skipping 418.mp4, already processed.
# Skipping 419.mp4, already processed.
# Skipping 420.mp4, already processed.
# Skipping 421.mp4, already processed.
# Skipping 422.mp4, already processed.
# Skipping 423.mp4, already processed.
# Skipping 424.mp4, already processed.
# Skipping 425.mp4, already processed.
# Skipping 426.mp4, already processed.
# Skipping 427.mp4, already processed.
# Skipping 428.mp4, already processed.
# Skipping 429.mp4, already processed.
# Skipping 430.mp4, already processed.
# Skipping 431.mp4, already processed.
# Skipping 432.mp4, already processed.
# Skipping 433.mp4, already processed.
# Skipping 434.mp4, already processed.
# Skipping 435.mp4, already processed.
# Skipping 436.mp4, already processed.
# Skipping 437.mp4, already processed.
# Skipping 438.mp4, already processed.
# Skipping 439.mp4, already processed.
# Skipping 440.mp4, already processed.
# Skipping 441.mp4, already processed.
# Skipping 442.mp4, already processed.
# Skipping 443.mp4, already processed.
# Skipping 444.mp4, already processed.
# Skipping 445.mp4, already processed.
# Skipping 446.mp4, already processed.
# Skipping 447.mp4, already processed.
# Skipping 448.mp4, already processed.
# Skipping 449.mp4, already processed.
# Skipping 450.mp4, already processed.
# Skipping 451.mp4, already processed.
# Skipping 452.mp4, already processed.
# Skipping 453.mp4, already processed.
# Skipping 454.mp4, already processed.
# Skipping 455.mp4, already processed.
# Skipping 456.mp4, already processed.
# Skipping 457.mp4, already processed.
# Skipping 458.mp4, already processed.
# Skipping 459.mp4, already processed.
# Skipping 460.mp4, already processed.
# Skipping 461.mp4, already processed.
# Skipping 462.mp4, already processed.
# Skipping 463.mp4, already processed.
# Skipping 464.mp4, already processed.
# Skipping 465.mp4, already processed.
# Skipping 466.mp4, already processed.
# Skipping 467.mp4, already processed.
# Skipping 468.mp4, already processed.
# Skipping 469.mp4, already processed.
# Skipping 470.mp4, already processed.
# Skipping 471.mp4, already processed.
# Skipping 472.mp4, already processed.
# Skipping 473.mp4, already processed.
# Skipping 474.mp4, already processed.
# Skipping 475.mp4, already processed.
# Skipping 476.mp4, already processed.
# Skipping 477.mp4, already processed.
# Skipping 478.mp4, already processed.
# Skipping 479.mp4, already processed.
# Skipping 480.mp4, already processed.
# Skipping 481.mp4, already processed.
# Skipping 482.mp4, already processed.
# Skipping 483.mp4, already processed.
# Skipping 484.mp4, already processed.
# Skipping 485.mp4, already processed.
# Skipping 486.mp4, already processed.
# Skipping 487.mp4, already processed.
# Skipping 488.mp4, already processed.
# Skipping 489.mp4, already processed.
# Skipping 490.mp4, already processed.
# Skipping 491.mp4, already processed.
# Skipping 492.mp4, already processed.
# Skipping 493.mp4, already processed.
# Skipping 494.mp4, already processed.
# Skipping 495.mp4, already processed.
# Skipping 496.mp4, already processed.
# Skipping 497.mp4, already processed.
# Skipping 498.mp4, already processed.
# Skipping 499.mp4, already processed.
# Skipping 500.mp4, already processed.
# Skipping 501.mp4, already processed.
# Skipping 502.mp4, already processed.
# Skipping 503.mp4, already processed.
# Skipping 504.mp4, already processed.
# Skipping 505.mp4, already processed.
# Skipping 506.mp4, already processed.
# Skipping 507.mp4, already processed.
# Skipping 508.mp4, already processed.
# Skipping 509.mp4, already processed.
# Skipping 510.mp4, already processed.
# Skipping 511.mp4, already processed.
# Skipping 512.mp4, already processed.
# Skipping 513.mp4, already processed.
# Skipping 514.mp4, already processed.
# Skipping 515.mp4, already processed.
# Skipping 516.mp4, already processed.
# Skipping 517.mp4, already processed.
# Skipping 518.mp4, already processed.
# Skipping 519.mp4, already processed.
# Skipping 520.mp4, already processed.
# Skipping 521.mp4, already processed.
# Skipping 522.mp4, already processed.
# Skipping 523.mp4, already processed.
# Skipping 524.mp4, already processed.
# Skipping 525.mp4, already processed.
# Skipping 526.mp4, already processed.
# Skipping 527.mp4, already processed.
# Skipping 528.mp4, already processed.
# Skipping 529.mp4, already processed.
# Skipping 530.mp4, already processed.
# Skipping 531.mp4, already processed.
# Skipping 532.mp4, already processed.
# Skipping 533.mp4, already processed.
# Skipping 534.mp4, already processed.
# Skipping 535.mp4, already processed.
# Skipping 536.mp4, already processed.
# Skipping 537.mp4, already processed.
# Skipping 538.mp4, already processed.
# Skipping 539.mp4, already processed.
# Skipping 540.mp4, already processed.
# Skipping 541.mp4, already processed.
# Skipping 542.mp4, already processed.
# Skipping 543.mp4, already processed.
# Skipping 544.mp4, already processed.
# Skipping 545.mp4, already processed.
# Skipping 546.mp4, already processed.
# Skipping 547.mp4, already processed.
# Skipping 548.mp4, already processed.
# Skipping 549.mp4, already processed.
# Skipping 550.mp4, already processed.
# Skipping 551.mp4, already processed.
# Skipping 552.mp4, already processed.
# Skipping 553.mp4, already processed.
# Skipping 554.mp4, already processed.
# Skipping 555.mp4, already processed.
# Skipping 556.mp4, already processed.
# Skipping 557.mp4, already processed.
# Skipping 558.mp4, already processed.
# Skipping 559.mp4, already processed.
# Skipping 560.mp4, already processed.
# Skipping 561.mp4, already processed.
# Skipping 562.mp4, already processed.
# Skipping 563.mp4, already processed.
# Skipping 564.mp4, already processed.
# Skipping 565.mp4, already processed.
# Skipping 566.mp4, already processed.
# Skipping 567.mp4, already processed.
# Skipping 568.mp4, already processed.
# Skipping 569.mp4, already processed.
# Skipping 570.mp4, already processed.
# Skipping 571.mp4, already processed.
# Skipping 572.mp4, already processed.
# Skipping 573.mp4, already processed.
# Skipping 574.mp4, already processed.
# Skipping 575.mp4, already processed.
# Skipping 576.mp4, already processed.
# Skipping 577.mp4, already processed.
# Skipping 578.mp4, already processed.
# Skipping 579.mp4, already processed.
# Skipping 580.mp4, already processed.
# Skipping 581.mp4, already processed.
# Skipping 582.mp4, already processed.
# Skipping 583.mp4, already processed.
# Skipping 584.mp4, already processed.
# Skipping 585.mp4, already processed.
# Skipping 586.mp4, already processed.
# Skipping 587.mp4, already processed.
# Skipping 588.mp4, already processed.
# Skipping 589.mp4, already processed.
# Skipping 590.mp4, already processed.
# Skipping 591.mp4, already processed.
# Skipping 592.mp4, already processed.
# Skipping 593.mp4, already processed.
# Skipping 594.mp4, already processed.
# Skipping 595.mp4, already processed.
# Skipping 596.mp4, already processed.
# Skipping 597.mp4, already processed.
# Skipping 598.mp4, already processed.
# Skipping 599.mp4, already processed.
# Skipping 600.mp4, already processed.
# Skipping 601.mp4, already processed.
# Skipping 602.mp4, already processed.
# Skipping 603.mp4, already processed.
# Skipping 604.mp4, already processed.
# Skipping 605.mp4, already processed.
# Skipping 606.mp4, already processed.
# Skipping 607.mp4, already processed.
# Skipping 608.mp4, already processed.
# Skipping 609.mp4, already processed.
# Skipping 610.mp4, already processed.
# Skipping 611.mp4, already processed.
# Skipping 612.mp4, already processed.
# Skipping 613.mp4, already processed.
# Skipping 614.mp4, already processed.
# Skipping 615.mp4, already processed.
# Skipping 616.mp4, already processed.
# Skipping 617.mp4, already processed.
# Skipping 618.mp4, already processed.
# Skipping 619.mp4, already processed.
# Skipping 620.mp4, already processed.
# Skipping 621.mp4, already processed.
# Skipping 622.mp4, already processed.
# Skipping 623.mp4, already processed.
# Skipping 624.mp4, already processed.
# Skipping 625.mp4, already processed.
# Skipping 626.mp4, already processed.
# Skipping 627.mp4, already processed.
# Skipping 628.mp4, already processed.
# Skipping 629.mp4, already processed.
# Skipping 630.mp4, already processed.
# Skipping 631.mp4, already processed.
# Skipping 632.mp4, already processed.
# Skipping 633.mp4, already processed.
# Skipping 634.mp4, already processed.
# Skipping 635.mp4, already processed.
# Skipping 636.mp4, already processed.
# Skipping 637.mp4, already processed.
# Skipping 638.mp4, already processed.
# Skipping 639.mp4, already processed.
# Skipping 640.mp4, already processed.
# Skipping 641.mp4, already processed.
# Skipping 642.mp4, already processed.
# Skipping 643.mp4, already processed.
# Skipping 644.mp4, already processed.
# Skipping 645.mp4, already processed.
# Skipping 646.mp4, already processed.
# Skipping 647.mp4, already processed.
# Skipping 648.mp4, already processed.
# Skipping 649.mp4, already processed.
# Skipping 650.mp4, already processed.
# Skipping 651.mp4, already processed.
# Skipping 652.mp4, already processed.
# Skipping 653.mp4, already processed.
# Skipping 654.mp4, already processed.
# Skipping 655.mp4, already processed.
# Skipping 656.mp4, already processed.
# Skipping 657.mp4, already processed.
# Skipping 658.mp4, already processed.
# Skipping 659.mp4, already processed.
# Skipping 660.mp4, already processed.
# Skipping 661.mp4, already processed.
# Skipping 662.mp4, already processed.
# Skipping 663.mp4, already processed.
# Skipping 664.mp4, already processed.
# Skipping 665.mp4, already processed.
# Skipping 666.mp4, already processed.
# Skipping 667.mp4, already processed.
# Skipping 668.mp4, already processed.
# Skipping 669.mp4, already processed.
# Skipping 670.mp4, already processed.
# Skipping 671.mp4, already processed.
# Skipping 672.mp4, already processed.
# Skipping 673.mp4, already processed.
# Skipping 674.mp4, already processed.
# Skipping 675.mp4, already processed.
# Skipping 676.mp4, already processed.
# Skipping 677.mp4, already processed.
# Skipping 678.mp4, already processed.
# Skipping 679.mp4, already processed.
# Skipping 680.mp4, already processed.
# Skipping 681.mp4, already processed.
# Skipping 682.mp4, already processed.
# Skipping 683.mp4, already processed.
# Skipping 684.mp4, already processed.
# Skipping 685.mp4, already processed.
# Skipping 686.mp4, already processed.
# Skipping 687.mp4, already processed.
# Skipping 688.mp4, already processed.
# Skipping 689.mp4, already processed.
# Skipping 690.mp4, already processed.
# Skipping 691.mp4, already processed.
# Skipping 692.mp4, already processed.
# Skipping 693.mp4, already processed.
# Skipping 694.mp4, already processed.
# Skipping 695.mp4, already processed.
# Skipping 696.mp4, already processed.
# Skipping 697.mp4, already processed.
# Skipping 698.mp4, already processed.
# Skipping 699.mp4, already processed.
# Skipping 700.mp4, already processed.
# Skipping 701.mp4, already processed.
# Skipping 702.mp4, already processed.
# Skipping 703.mp4, already processed.
# Skipping 704.mp4, already processed.
# Skipping 705.mp4, already processed.
# Skipping 706.mp4, already processed.
# Skipping 707.mp4, already processed.
# Skipping 708.mp4, already processed.
# Skipping 709.mp4, already processed.
# Skipping 710.mp4, already processed.
# Skipping 711.mp4, already processed.
# Skipping 712.mp4, already processed.
# Skipping 713.mp4, already processed.
# Skipping 714.mp4, already processed.
# Skipping 715.mp4, already processed.
# Skipping 716.mp4, already processed.
# Skipping 717.mp4, already processed.
# Skipping 718.mp4, already processed.
# Skipping 719.mp4, already processed.
# Skipping 720.mp4, already processed.
# Skipping 721.mp4, already processed.
# Skipping 722.mp4, already processed.
# Skipping 723.mp4, already processed.
# Skipping 724.mp4, already processed.
# Skipping 725.mp4, already processed.
# Skipping 726.mp4, already processed.
# Skipping 727.mp4, already processed.
# Skipping 728.mp4, already processed.
# Skipping 729.mp4, already processed.
# Skipping 730.mp4, already processed.
# Skipping 731.mp4, already processed.
# Skipping 732.mp4, already processed.
# Skipping 733.mp4, already processed.
# Skipping 734.mp4, already processed.
# Skipping 735.mp4, already processed.
# Skipping 736.mp4, already processed.
# Skipping 737.mp4, already processed.
# Skipping 738.mp4, already processed.
# Skipping 739.mp4, already processed.
# Skipping 740.mp4, already processed.
# Skipping 741.mp4, already processed.
# Skipping 742.mp4, already processed.
# Skipping 743.mp4, already processed.
# Skipping 744.mp4, already processed.
# Skipping 745.mp4, already processed.
# Skipping 746.mp4, already processed.
# Skipping 747.mp4, already processed.
# Skipping 748.mp4, already processed.
# Skipping 749.mp4, already processed.
# Skipping 750.mp4, already processed.
# Skipping 751.mp4, already processed.
# Skipping 752.mp4, already processed.
# Skipping 753.mp4, already processed.
# Skipping 754.mp4, already processed.
# Skipping 755.mp4, already processed.
# Skipping 756.mp4, already processed.
# Skipping 757.mp4, already processed.
# Skipping 758.mp4, already processed.
# Skipping 759.mp4, already processed.
# Skipping 760.mp4, already processed.
# Skipping 761.mp4, already processed.
# Skipping 762.mp4, already processed.
# Skipping 763.mp4, already processed.
# Skipping 764.mp4, already processed.
# Skipping 765.mp4, already processed.
# Skipping 766.mp4, already processed.
# Skipping 767.mp4, already processed.
# Skipping 768.mp4, already processed.
# Skipping 769.mp4, already processed.
# Skipping 770.mp4, already processed.
# Skipping 771.mp4, already processed.
# Skipping 772.mp4, already processed.
# Skipping 773.mp4, already processed.
# Skipping 774.mp4, already processed.
# Skipping 775.mp4, already processed.
# Skipping 776.mp4, already processed.
# Skipping 777.mp4, already processed.
# Skipping 778.mp4, already processed.
# Skipping 779.mp4, already processed.
# Skipping 780.mp4, already processed.
# Skipping 781.mp4, already processed.
# Skipping 782.mp4, already processed.
# Skipping 783.mp4, already processed.
# Skipping 784.mp4, already processed.
# Skipping 785.mp4, already processed.
# Skipping 786.mp4, already processed.
# Skipping 787.mp4, already processed.
# Skipping 788.mp4, already processed.
# Skipping 789.mp4, already processed.
# Skipping 790.mp4, already processed.
# Skipping 791.mp4, already processed.
# Skipping 792.mp4, already processed.
# Skipping 793.mp4, already processed.
# Skipping 794.mp4, already processed.
# Skipping 795.mp4, already processed.
# Skipping 796.mp4, already processed.
# Skipping 797.mp4, already processed.
# Skipping 798.mp4, already processed.
# Skipping 799.mp4, already processed.
# Skipping 800.mp4, already processed.
# Skipping 801.mp4, already processed.
# Skipping 802.mp4, already processed.
# Skipping 803.mp4, already processed.
# Skipping 804.mp4, already processed.
# Skipping 805.mp4, already processed.
# Skipping 806.mp4, already processed.
# Skipping 807.mp4, already processed.
# Skipping 808.mp4, already processed.
# Skipping 809.mp4, already processed.
# Skipping 810.mp4, already processed.
# Skipping 811.mp4, already processed.
# Skipping 812.mp4, already processed.
# Skipping 813.mp4, already processed.
# Skipping 814.mp4, already processed.
# Skipping 815.mp4, already processed.
# Skipping 816.mp4, already processed.
# Skipping 817.mp4, already processed.
# Skipping 818.mp4, already processed.
# Skipping 819.mp4, already processed.
# Skipping 820.mp4, already processed.
# Skipping 821.mp4, already processed.
# Skipping 822.mp4, already processed.
# Skipping 823.mp4, already processed.
# Skipping 824.mp4, already processed.
# Skipping 825.mp4, already processed.
# Skipping 826.mp4, already processed.
# Skipping 827.mp4, already processed.
# Skipping 828.mp4, already processed.
# Skipping 829.mp4, already processed.
# Skipping 830.mp4, already processed.
# Skipping 831.mp4, already processed.
# Skipping 832.mp4, already processed.
# Skipping 833.mp4, already processed.
# Skipping 834.mp4, already processed.
# Skipping 835.mp4, already processed.
# Skipping 836.mp4, already processed.
# Skipping 837.mp4, already processed.
# Skipping 838.mp4, already processed.
# Skipping 839.mp4, already processed.
# Skipping 840.mp4, already processed.
# Skipping 841.mp4, already processed.
# Skipping 842.mp4, already processed.
# Skipping 843.mp4, already processed.
# Skipping 844.mp4, already processed.
# Skipping 845.mp4, already processed.
# Skipping 846.mp4, already processed.
# Skipping 847.mp4, already processed.
# Skipping 848.mp4, already processed.
# Skipping 849.mp4, already processed.
# Skipping 850.mp4, already processed.
# Skipping 851.mp4, already processed.
# Skipping 852.mp4, already processed.
# Skipping 853.mp4, already processed.
# Skipping 854.mp4, already processed.
# Skipping 855.mp4, already processed.
# Skipping 856.mp4, already processed.
# Skipping 857.mp4, already processed.
# Skipping 858.mp4, already processed.
# Skipping 859.mp4, already processed.
# Skipping 860.mp4, already processed.
# Skipping 861.mp4, already processed.
# Skipping 862.mp4, already processed.
# Skipping 863.mp4, already processed.
# Skipping 864.mp4, already processed.
# Skipping 865.mp4, already processed.
# Skipping 866.mp4, already processed.
# Skipping 867.mp4, already processed.
# Skipping 868.mp4, already processed.
# Skipping 869.mp4, already processed.
# Skipping 870.mp4, already processed.
# Skipping 871.mp4, already processed.
# Skipping 872.mp4, already processed.
# Skipping 873.mp4, already processed.
# Skipping 874.mp4, already processed.
# Skipping 875.mp4, already processed.
# Skipping 876.mp4, already processed.
# Skipping 877.mp4, already processed.
# Skipping 878.mp4, already processed.
# Skipping 879.mp4, already processed.
# Skipping 880.mp4, already processed.
# Skipping 881.mp4, already processed.
# Skipping 882.mp4, already processed.
# Skipping 883.mp4, already processed.
# Skipping 884.mp4, already processed.
# Skipping 885.mp4, already processed.
# Skipping 886.mp4, already processed.
# Skipping 887.mp4, already processed.
# Skipping 888.mp4, already processed.
# Skipping 889.mp4, already processed.
# Skipping 890.mp4, already processed.
# Skipping 891.mp4, already processed.
# Skipping 892.mp4, already processed.
# Skipping 893.mp4, already processed.
# Skipping 894.mp4, already processed.
# Skipping 895.mp4, already processed.
# Skipping 896.mp4, already processed.
# Skipping 897.mp4, already processed.
# Skipping 898.mp4, already processed.
# Skipping 899.mp4, already processed.
# Skipping 900.mp4, already processed.
# Skipping 901.mp4, already processed.
# Skipping 902.mp4, already processed.
# Skipping 903.mp4, already processed.
# Skipping 904.mp4, already processed.
# Skipping 905.mp4, already processed.
# Skipping 906.mp4, already processed.
# Skipping 907.mp4, already processed.
# Skipping 908.mp4, already processed.
# Skipping 909.mp4, already processed.
# Skipping 910.mp4, already processed.
# Skipping 911.mp4, already processed.
# Skipping 912.mp4, already processed.
# Skipping 913.mp4, already processed.
# Skipping 914.mp4, already processed.
# Skipping 915.mp4, already processed.
# Skipping 916.mp4, already processed.
# Skipping 917.mp4, already processed.
# Skipping 918.mp4, already processed.
# Skipping 919.mp4, already processed.
# Skipping 920.mp4, already processed.
# Skipping 921.mp4, already processed.
# Skipping 922.mp4, already processed.
# Skipping 923.mp4, already processed.
# Skipping 924.mp4, already processed.
# Skipping 925.mp4, already processed.
# Skipping 926.mp4, already processed.
# Skipping 927.mp4, already processed.
# Skipping 928.mp4, already processed.
# Skipping 929.mp4, already processed.
# Skipping 930.mp4, already processed.
# Skipping 931.mp4, already processed.
# Skipping 932.mp4, already processed.
# Skipping 933.mp4, already processed.
# Skipping 934.mp4, already processed.
# Skipping 935.mp4, already processed.
# Skipping 936.mp4, already processed.
# Skipping 937.mp4, already processed.
# Skipping 938.mp4, already processed.
# Skipping 939.mp4, already processed.
# Skipping 940.mp4, already processed.
# Skipping 941.mp4, already processed.
# Skipping 942.mp4, already processed.
# Skipping 943.mp4, already processed.
# Skipping 944.mp4, already processed.
# Skipping 945.mp4, already processed.
# Skipping 946.mp4, already processed.
# Skipping 947.mp4, already processed.
# Skipping 948.mp4, already processed.
# Skipping 949.mp4, already processed.
# Skipping 950.mp4, already processed.
# Skipping 951.mp4, already processed.
# Skipping 952.mp4, already processed.
# Skipping 953.mp4, already processed.
# Skipping 954.mp4, already processed.
# Skipping 955.mp4, already processed.
# Skipping 956.mp4, already processed.
# Skipping 957.mp4, already processed.
# Skipping 958.mp4, already processed.
# Skipping 959.mp4, already processed.
# Skipping 960.mp4, already processed.
# Skipping 961.mp4, already processed.
# Skipping 962.mp4, already processed.
# Skipping 963.mp4, already processed.
# Skipping 964.mp4, already processed.
# Skipping 965.mp4, already processed.
# Skipping 966.mp4, already processed.
# Skipping 967.mp4, already processed.
# Skipping 968.mp4, already processed.
# Skipping 969.mp4, already processed.
# Skipping 970.mp4, already processed.
# Skipping 971.mp4, already processed.
# Skipping 972.mp4, already processed.
# Skipping 973.mp4, already processed.
# Skipping 974.mp4, already processed.
# Skipping 975.mp4, already processed.
# Skipping 976.mp4, already processed.
# Skipping 977.mp4, already processed.
# Skipping 978.mp4, already processed.
# Skipping 979.mp4, already processed.
# Skipping 980.mp4, already processed.
# Skipping 981.mp4, already processed.
# Skipping 982.mp4, already processed.
# Skipping 983.mp4, already processed.
# Skipping 984.mp4, already processed.
# Skipping 985.mp4, already processed.
# Skipping 986.mp4, already processed.
# Skipping 987.mp4, already processed.
# Skipping 988.mp4, already processed.
# Skipping 989.mp4, already processed.
# Skipping 990.mp4, already processed.
# Skipping 991.mp4, already processed.
# Skipping 992.mp4, already processed.
# Skipping 993.mp4, already processed.
# Skipping 994.mp4, already processed.
# Skipping 995.mp4, already processed.
# Skipping 996.mp4, already processed.
# Skipping 997.mp4, already processed.
# Skipping 998.mp4, already processed.
# Skipping 999.mp4, already processed.
# Skipping 000_003.mp4, already processed.
# Skipping 001_870.mp4, already processed.
# Skipping 002_006.mp4, already processed.
# Skipping 003_000.mp4, already processed.
# Skipping 004_982.mp4, already processed.
# Skipping 005_010.mp4, already processed.
# Skipping 006_002.mp4, already processed.
# Skipping 007_132.mp4, already processed.
# Skipping 008_990.mp4, already processed.
# Skipping 009_027.mp4, already processed.
# Skipping 010_005.mp4, already processed.
# Skipping 011_805.mp4, already processed.
# Skipping 012_026.mp4, already processed.
# Skipping 013_883.mp4, already processed.
# Skipping 014_790.mp4, already processed.
# Skipping 015_919.mp4, already processed.
# Skipping 016_209.mp4, already processed.
# Skipping 017_803.mp4, already processed.
# Skipping 018_019.mp4, already processed.
# Skipping 019_018.mp4, already processed.
# Skipping 020_344.mp4, already processed.
# Skipping 021_312.mp4, already processed.
# Skipping 022_489.mp4, already processed.
# Skipping 023_923.mp4, already processed.
# Skipping 024_073.mp4, already processed.
# Skipping 025_067.mp4, already processed.
# Skipping 026_012.mp4, already processed.
# Skipping 027_009.mp4, already processed.
# Skipping 028_068.mp4, already processed.
# Skipping 029_048.mp4, already processed.
# Skipping 030_193.mp4, already processed.
# Skipping 031_163.mp4, already processed.
# Skipping 032_944.mp4, already processed.
# Skipping 033_097.mp4, already processed.
# Skipping 034_590.mp4, already processed.
# Skipping 035_036.mp4, already processed.
# Skipping 036_035.mp4, already processed.
# Skipping 037_072.mp4, already processed.
# Skipping 038_125.mp4, already processed.
# Skipping 039_058.mp4, already processed.
# Skipping 040_997.mp4, already processed.
# Skipping 041_063.mp4, already processed.
# Skipping 042_084.mp4, already processed.
# Skipping 043_110.mp4, already processed.
# Skipping 044_945.mp4, already processed.
# Skipping 045_889.mp4, already processed.
# Skipping 046_904.mp4, already processed.
# Skipping 047_862.mp4, already processed.
# Skipping 048_029.mp4, already processed.
# Skipping 049_946.mp4, already processed.
# Skipping 050_059.mp4, already processed.
# Skipping 051_332.mp4, already processed.
# Skipping 052_108.mp4, already processed.
# Skipping 053_095.mp4, already processed.
# Skipping 054_071.mp4, already processed.
# Skipping 055_147.mp4, already processed.
# Skipping 056_996.mp4, already processed.
# Skipping 057_070.mp4, already processed.
# Skipping 058_039.mp4, already processed.
# Skipping 059_050.mp4, already processed.
# Skipping 060_088.mp4, already processed.
# Skipping 061_080.mp4, already processed.
# Skipping 062_066.mp4, already processed.
# Skipping 063_041.mp4, already processed.
# Skipping 064_991.mp4, already processed.
# Skipping 065_089.mp4, already processed.
# Skipping 066_062.mp4, already processed.
# Skipping 067_025.mp4, already processed.
# Skipping 068_028.mp4, already processed.
# Skipping 069_961.mp4, already processed.
# Skipping 070_057.mp4, already processed.
# Skipping 071_054.mp4, already processed.
# Skipping 072_037.mp4, already processed.
# Skipping 073_024.mp4, already processed.
# Skipping 074_825.mp4, already processed.
# Skipping 075_977.mp4, already processed.
# Skipping 076_079.mp4, already processed.
# Skipping 077_100.mp4, already processed.
# Skipping 078_955.mp4, already processed.
# Skipping 079_076.mp4, already processed.
# Skipping 080_061.mp4, already processed.
# Skipping 081_087.mp4, already processed.
# Skipping 082_103.mp4, already processed.
# Skipping 083_213.mp4, already processed.
# Skipping 084_042.mp4, already processed.
# Skipping 085_124.mp4, already processed.
# Skipping 086_090.mp4, already processed.
# Skipping 087_081.mp4, already processed.
# Skipping 088_060.mp4, already processed.
# Skipping 089_065.mp4, already processed.
# Skipping 090_086.mp4, already processed.
# Skipping 091_116.mp4, already processed.
# Skipping 092_098.mp4, already processed.
# Skipping 093_121.mp4, already processed.
# Skipping 094_111.mp4, already processed.
# Skipping 095_053.mp4, already processed.
# Skipping 096_101.mp4, already processed.
# Skipping 097_033.mp4, already processed.
# Skipping 098_092.mp4, already processed.
# Skipping 099_295.mp4, already processed.
# Skipping 100_077.mp4, already processed.
# Skipping 101_096.mp4, already processed.
# Skipping 102_114.mp4, already processed.
# Skipping 103_082.mp4, already processed.
# Skipping 104_126.mp4, already processed.
# Skipping 105_180.mp4, already processed.
# Skipping 106_198.mp4, already processed.
# Skipping 107_109.mp4, already processed.
# Skipping 108_052.mp4, already processed.
# Skipping 109_107.mp4, already processed.
# Skipping 110_043.mp4, already processed.
# Skipping 111_094.mp4, already processed.
# Skipping 112_892.mp4, already processed.
# Skipping 113_983.mp4, already processed.
# Skipping 114_102.mp4, already processed.
# Skipping 115_939.mp4, already processed.
# Skipping 116_091.mp4, already processed.
# Skipping 117_217.mp4, already processed.
# Skipping 118_120.mp4, already processed.
# Skipping 119_123.mp4, already processed.
# Skipping 120_118.mp4, already processed.
# Skipping 121_093.mp4, already processed.
# Skipping 122_144.mp4, already processed.
# Skipping 123_119.mp4, already processed.
# Skipping 124_085.mp4, already processed.
# Skipping 125_038.mp4, already processed.
# Skipping 126_104.mp4, already processed.
# Skipping 127_129.mp4, already processed.
# Skipping 128_896.mp4, already processed.
# Skipping 129_127.mp4, already processed.
# Skipping 130_139.mp4, already processed.
# Skipping 131_518.mp4, already processed.
# Skipping 132_007.mp4, already processed.
# Skipping 133_148.mp4, already processed.
# Skipping 134_192.mp4, already processed.
# Skipping 135_880.mp4, already processed.
# Skipping 136_285.mp4, already processed.
# Skipping 137_165.mp4, already processed.
# Skipping 138_142.mp4, already processed.
# Skipping 139_130.mp4, already processed.
# Skipping 140_143.mp4, already processed.
# Skipping 141_161.mp4, already processed.
# Skipping 142_138.mp4, already processed.
# Skipping 143_140.mp4, already processed.
# Skipping 144_122.mp4, already processed.
# Skipping 145_299.mp4, already processed.
# Skipping 146_256.mp4, already processed.
# Skipping 147_055.mp4, already processed.
# Skipping 148_133.mp4, already processed.
# Skipping 149_152.mp4, already processed.
# Skipping 150_153.mp4, already processed.
# Skipping 151_225.mp4, already processed.
# Skipping 152_149.mp4, already processed.
# Skipping 153_150.mp4, already processed.
# Skipping 154_386.mp4, already processed.
# Skipping 155_576.mp4, already processed.
# Skipping 156_243.mp4, already processed.
# Skipping 157_245.mp4, already processed.
# Skipping 158_379.mp4, already processed.
# Skipping 159_175.mp4, already processed.
# Skipping 160_928.mp4, already processed.
# Skipping 161_141.mp4, already processed.
# Skipping 162_330.mp4, already processed.
# Skipping 163_031.mp4, already processed.
# Skipping 164_216.mp4, already processed.
# Skipping 165_137.mp4, already processed.
# Skipping 166_167.mp4, already processed.
# Skipping 167_166.mp4, already processed.
# Skipping 168_222.mp4, already processed.
# Skipping 169_227.mp4, already processed.
# Skipping 170_186.mp4, already processed.
# Skipping 171_173.mp4, already processed.
# Skipping 172_582.mp4, already processed.
# Skipping 173_171.mp4, already processed.
# Skipping 174_964.mp4, already processed.
# Skipping 175_159.mp4, already processed.
# Skipping 176_190.mp4, already processed.
# Skipping 177_211.mp4, already processed.
# Skipping 178_598.mp4, already processed.
# Skipping 179_212.mp4, already processed.
# Skipping 180_105.mp4, already processed.
# Skipping 181_199.mp4, already processed.
# Skipping 182_242.mp4, already processed.
# Skipping 183_253.mp4, already processed.
# Skipping 184_205.mp4, already processed.
# Skipping 185_276.mp4, already processed.
# Skipping 186_170.mp4, already processed.
# Skipping 187_234.mp4, already processed.
# Skipping 188_191.mp4, already processed.
# Skipping 189_200.mp4, already processed.
# Skipping 190_176.mp4, already processed.
# Skipping 191_188.mp4, already processed.
# Skipping 192_134.mp4, already processed.
# Skipping 193_030.mp4, already processed.
# Skipping 194_235.mp4, already processed.
# Skipping 195_442.mp4, already processed.
# Skipping 196_310.mp4, already processed.
# Skipping 197_224.mp4, already processed.
# Skipping 198_106.mp4, already processed.
# Skipping 199_181.mp4, already processed.
# Skipping 200_189.mp4, already processed.
# Skipping 201_203.mp4, already processed.
# Skipping 202_348.mp4, already processed.
# Skipping 203_201.mp4, already processed.
# Skipping 204_230.mp4, already processed.
# Skipping 205_184.mp4, already processed.
# Skipping 206_221.mp4, already processed.
# Skipping 207_908.mp4, already processed.
# Skipping 208_215.mp4, already processed.
# Skipping 209_016.mp4, already processed.
# Skipping 210_241.mp4, already processed.
# Skipping 211_177.mp4, already processed.
# Skipping 212_179.mp4, already processed.
# Skipping 213_083.mp4, already processed.
# Skipping 214_255.mp4, already processed.
# Skipping 215_208.mp4, already processed.
# Skipping 216_164.mp4, already processed.
# Skipping 217_117.mp4, already processed.
# Skipping 218_239.mp4, already processed.
# Skipping 219_220.mp4, already processed.
# Skipping 220_219.mp4, already processed.
# Skipping 221_206.mp4, already processed.
# Skipping 222_168.mp4, already processed.
# Skipping 223_586.mp4, already processed.
# Skipping 224_197.mp4, already processed.
# Skipping 225_151.mp4, already processed.
# Skipping 226_491.mp4, already processed.
# Skipping 227_169.mp4, already processed.
# Skipping 228_289.mp4, already processed.
# Skipping 229_247.mp4, already processed.
# Skipping 230_204.mp4, already processed.
# Skipping 231_663.mp4, already processed.
# Skipping 232_248.mp4, already processed.
# Skipping 233_995.mp4, already processed.
# Skipping 234_187.mp4, already processed.
# Skipping 235_194.mp4, already processed.
# Skipping 236_237.mp4, already processed.
# Skipping 237_236.mp4, already processed.
# Skipping 238_282.mp4, already processed.
# Skipping 239_218.mp4, already processed.
# Skipping 240_290.mp4, already processed.
# Skipping 241_210.mp4, already processed.
# Skipping 242_182.mp4, already processed.
# Skipping 243_156.mp4, already processed.
# Skipping 244_822.mp4, already processed.
# Skipping 245_157.mp4, already processed.
# Skipping 246_258.mp4, already processed.
# Skipping 247_229.mp4, already processed.
# Dataset updated and saved.
