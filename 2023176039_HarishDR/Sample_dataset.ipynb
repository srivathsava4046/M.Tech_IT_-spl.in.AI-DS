# %%
import json

# %%
with open("D:/Project_phase_1/Preprocess/captions_train2014.json") as f:
  data = json.load(f)

# %%
data
# Out:
# {'318556': ['A very clean and well decorated empty bathroom',
#   'A blue and white bathroom with butterfly themed wall tiles.',
#   'A bathroom with a border of butterflies and blue paint on the walls above it.',
#   'An angled view of a beautifully decorated bathroom.',
#   'A clock that blends in with the wall hangs in a bathroom. '],
#  '116100': ['A panoramic view of a kitchen and all of its appliances.',
#   'A panoramic photo of a kitchen and dining room',
#   'A wide angle view of the kitchen work area',
#   'multiple photos of a brown and white kitchen. ',
#   'A kitchen that has a checkered patterned floor and white cabinets.'],
#  '379340': ['A graffiti-ed stop sign across the street from a red car ',
#   'A vandalized stop sign and a red beetle on the road',
#   'A red stop sign with a Bush bumper sticker under the word stop.',
#   'A stop sign that has been vandalized is pictured in front of a parked car.',
#   'A street sign modified to read stop bush.'],
# ...

# %%
with open("D:/Project_phase_1/Preprocess/captions_val2014.json") as g:
    df=json.load(g)

# %%
df
# Out:
# {'info': {'description': 'This is stable 1.0 version of the 2014 MS COCO dataset.',
#   'url': 'http://mscoco.org',
#   'version': '1.0',
#   'year': 2014,
#   'contributor': 'Microsoft COCO group',
#   'date_created': '2015-01-27 09:11:52.357475'},
#  'images': [{'license': 3,
#    'file_name': 'COCO_val2014_000000391895.jpg',
#    'coco_url': 'http://mscoco.org/images/391895',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-14 11:18:45',
#    'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#    'id': 391895},
#   {'license': 4,
#    'file_name': 'COCO_val2014_000000522418.jpg',
#    'coco_url': 'http://mscoco.org/images/522418',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-14 11:38:44',
#    'flickr_url': 'http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg',
#    'id': 522418},
#   {'license': 3,
#    'file_name': 'COCO_val2014_000000184613.jpg',
# ...

# %%
with open("D:/Project_phase_1/Preprocess/Questions_Train_abstract_v002/MultipleChoice_abstract_v002_train2015_questions.json") as a:
    df=json.load(a)

# %%
df
# Out:
# {'info': {'description': 'This is v1.0 of the VQA dataset.',
#   'url': 'http://visualqa.org',
#   'version': '1.0',
#   'year': 2015,
#   'contributor': 'VQA Team',
#   'date_created': '2015-10-02 19:50:08'},
#  'task_type': 'Multiple-Choice',
#  'data_type': 'abstract_v002',
#  'license': {'url': 'http://creativecommons.org/licenses/by/4.0/',
#   'name': 'Creative Commons Attribution 4.0 International License'},
#  'questions': [{'image_id': 11779,
#    'question': 'Who looks happier?',
#    'multiple_choices': ['alive',
#     '1',
#     'woman',
#     'purple',
#     '2',
#     'yes',
#     'white',
#     'boy',
#     'she loves him',
#     'mountain',
#     '3',
#     'no',
#     'baby',
#     'man',
#     'yellow',
#     'red',
#     '4',
#     'blue'],
#    'question_id': 117792},
#   {'image_id': 11779,
#    'question': 'Where is the woman sitting?',
#    'multiple_choices': ['3',
#     'no',
#     'blue',
#     'red',
#     '1',
# ...

# %%
with open("D:/Project_phase_1/Preprocess/Questions_Train_abstract_v002/OpenEnded_abstract_v002_train2015_questions.json") as b:
    df=json.load(b)

# %%
df
# Out:
# {'info': {'description': 'This is v1.0 of the VQA dataset.',
#   'url': 'http://visualqa.org',
#   'version': '1.0',
#   'year': 2015,
#   'contributor': 'VQA Team',
#   'date_created': '2015-10-02 19:48:55'},
#  'task_type': 'Open-Ended',
#  'data_type': 'abstract_v002',
#  'license': {'url': 'http://creativecommons.org/licenses/by/4.0/',
#   'name': 'Creative Commons Attribution 4.0 International License'},
#  'data_subtype': 'train2015',
#  'questions': [{'question': 'Who looks happier?',
#    'image_id': 11779,
#    'question_id': 117792},
#   {'question': 'Where is the woman sitting?',
#    'image_id': 11779,
#    'question_id': 117790},
#   {'question': 'Where is the man sitting?',
#    'image_id': 11779,
#    'question_id': 117791},
#   {'question': 'Is this man hungry?', 'image_id': 5536, 'question_id': 55360},
#   {'question': 'What kind of drink is that?',
#    'image_id': 5536,
#    'question_id': 55361},
#   {'question': 'What color is the carpet?',
# ...

# %%
from IPython.display import Image
Image(filename='D:/Project_phase_1/scene_img_abstract_v002_train2015/abstract_v002_train2015_000000000000.png')

# %%
from IPython.display import Image
Image(filename='D:/Project_phase_1/train2014/COCO_train2014_000000000009.jpg')
