# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # InceptionV3 model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score
import pickle

# Define the paths
augmented_train_dir = r'C:\Users\kaush\Downloads\indian skins scrapped\augmented_train'  # Directory containing all data
test_dir = r'C:\Users\kaush\Downloads\indian skins scrapped\train\testing'  # Path for test data

# Image data generator for preprocessing (normalization only) with 80-20 split
datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0, 1]
    validation_split=0.20  # 20% validation split
)

# Load the training data (80% of the data)
train_data = datagen.flow_from_directory(
    augmented_train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training',  # Use 'training' subset (80%)
    shuffle=True
)

# Load the validation data (20% of the data)
val_data = datagen.flow_from_directory(
    augmented_train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',  # Use 'validation' subset (20%)
    shuffle=True
)

# Load the test data (not augmented)
test_data = datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Build the InceptionV3 model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
base_model.trainable = False

# Build the model
model = Sequential([
    base_model,
    Flatten(),  # Flatten the output from the convolutional base
    Dropout(0.5),  # Add dropout to reduce overfitting
    Dense(3, activation='softmax')  # Output layer for 3 classes
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Save the best model during training
model_name = "InceptionV3_skin_classification"  # Set the model name for identification
checkpoint = ModelCheckpoint(f'{model_name}_best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20,  # Adjust epochs as needed
    callbacks=[checkpoint]
)

# Save the training history
with open(f'{model_name}_training_history.pkl', 'wb') as file:
    pickle.dump(history.history, file)

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

# Function to print precision, recall, and F1 score
def print_classification_metrics(data, dataset_name):
    data.reset()  # Reset data generator
    predictions = model.predict(data)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = data.classes
    
    # Calculate precision, recall, and F1 score
    precision = precision_score(true_classes, predicted_classes, average='weighted')
    recall = recall_score(true_classes, predicted_classes, average='weighted')
    f1 = f1_score(true_classes, predicted_classes, average='weighted')
    
    # Print the metrics
    print(f"\n{dataset_name} Metrics:")
    print(f"Precision = {precision * 100:.2f}")
    print(f"Recall = {recall * 100:.2f}")
    print(f"F1 Score = {f1 * 100:.2f}")

# Print precision, recall, and F1 score for validation set
print_classification_metrics(val_data, "Validation Set")

# Print precision, recall, and F1 score for test set
print_classification_metrics(test_data, "Test Set")

# Print the training and validation accuracy and loss
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]

print(f"\nTraining Accuracy: {train_accuracy * 100:.2f}%")
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
print(f"Training Loss: {train_loss:.4f}")
print(f"Validation Loss: {val_loss:.4f}")
# Out:
# Found 521 images belonging to 3 classes.
# Found 129 images belonging to 3 classes.
# Found 17 images belonging to 3 classes.
# C:\Users\kaush\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.3304 - loss: 2.0084
# Epoch 1: val_accuracy improved from -inf to 0.46512, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.3315 - loss: 2.0060 - val_accuracy: 0.4651 - val_loss: 1.1474
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.5958 - loss: 1.1936
# Epoch 2: val_accuracy improved from 0.46512 to 0.51938, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5957 - loss: 1.1895 - val_accuracy: 0.5194 - val_loss: 0.9780
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.6258 - loss: 0.8713
# Epoch 3: val_accuracy improved from 0.51938 to 0.62016, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6261 - loss: 0.8729 - val_accuracy: 0.6202 - val_loss: 0.8990
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.6953 - loss: 0.7674
# Epoch 4: val_accuracy improved from 0.62016 to 0.64341, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6973 - loss: 0.7612 - val_accuracy: 0.6434 - val_loss: 0.9426
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.8027 - loss: 0.5131
# Epoch 5: val_accuracy improved from 0.64341 to 0.65116, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8027 - loss: 0.5119 - val_accuracy: 0.6512 - val_loss: 0.7972
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.8118 - loss: 0.4246
# Epoch 6: val_accuracy did not improve from 0.65116
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8140 - loss: 0.4220 - val_accuracy: 0.6512 - val_loss: 0.8153
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8575 - loss: 0.3534
# Epoch 7: val_accuracy improved from 0.65116 to 0.66667, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8584 - loss: 0.3515 - val_accuracy: 0.6667 - val_loss: 0.7308
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.8947 - loss: 0.2828
# Epoch 8: val_accuracy did not improve from 0.66667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8944 - loss: 0.2836 - val_accuracy: 0.6589 - val_loss: 0.7625
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - accuracy: 0.9167 - loss: 0.2495
# Epoch 9: val_accuracy improved from 0.66667 to 0.71318, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9162 - loss: 0.2489 - val_accuracy: 0.7132 - val_loss: 0.7226
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.9130 - loss: 0.2063
# Epoch 10: val_accuracy did not improve from 0.71318
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9130 - loss: 0.2071 - val_accuracy: 0.6977 - val_loss: 0.6877
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 892ms/step - accuracy: 0.9270 - loss: 0.1772
# Epoch 11: val_accuracy did not improve from 0.71318
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9274 - loss: 0.1772 - val_accuracy: 0.7054 - val_loss: 0.6802
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.9699 - loss: 0.1257
# Epoch 12: val_accuracy improved from 0.71318 to 0.72093, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9698 - loss: 0.1257 - val_accuracy: 0.7209 - val_loss: 0.7080
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.9615 - loss: 0.1255
# Epoch 13: val_accuracy improved from 0.72093 to 0.73643, saving model to InceptionV3_skin_classification_best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9613 - loss: 0.1251 - val_accuracy: 0.7364 - val_loss: 0.6642
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.9668 - loss: 0.1096
# Epoch 14: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9668 - loss: 0.1093 - val_accuracy: 0.7364 - val_loss: 0.6361
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.9786 - loss: 0.0922
# Epoch 15: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9783 - loss: 0.0925 - val_accuracy: 0.7287 - val_loss: 0.6603
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9700 - loss: 0.0923
# Epoch 16: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9704 - loss: 0.0920 - val_accuracy: 0.7209 - val_loss: 0.6609
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9803 - loss: 0.0722
# Epoch 17: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9799 - loss: 0.0728 - val_accuracy: 0.7364 - val_loss: 0.6618
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.9739 - loss: 0.0719
# Epoch 18: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9742 - loss: 0.0721 - val_accuracy: 0.7209 - val_loss: 0.6733
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.9901 - loss: 0.0512
# Epoch 19: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9897 - loss: 0.0518 - val_accuracy: 0.7287 - val_loss: 0.6429
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9914 - loss: 0.0527
# Epoch 20: val_accuracy did not improve from 0.73643
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9914 - loss: 0.0529 - val_accuracy: 0.7132 - val_loss: 0.6657
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step - accuracy: 0.7059 - loss: 0.6044
# Test Accuracy: 70.59%
# Test Loss: 0.6044
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
#
# Validation Set Metrics:
# Precision = 38.06
# Recall = 37.98
# F1 Score = 37.80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
#
# Test Set Metrics:
# Precision = 71.37
# Recall = 70.59
# F1 Score = 68.61
#
# Training Accuracy: 99.04%
# Validation Accuracy: 71.32%
# Training Loss: 0.0565
# Validation Loss: 0.6657
